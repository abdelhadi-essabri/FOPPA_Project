# %%
from functions.utils_lots import *
import warnings

warnings.filterwarnings('ignore')

# %%
lots = load_data(path='../donnees/Lots.csv')

# %%
lots
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 0              0     2010142              0          0  2009-09-24
# 1              1     2010142              0          0  2009-09-24
# 2              2     2010142              0          0  2009-09-24
# 3              3     2010143              0          0  2009-09-28
# 4              4     2010144              0          0  2009-11-06
# ...          ...         ...            ...        ...         ...
# 1380960  1380960  2020643360              0          0  2020-12-28
# 1380961  1380961  2020643361              0          0  2020-12-10
# 1380962  1380962  2020643362              0          0  2020-12-17
# 1380963  1380963  2020643363              0          0  2020-12-11
# 1380964  1380964  2020643364              0          0  2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                        NaN  8.916747e+05  45233226.0            NaN
# 1                        NaN  1.169251e+05  45233226.0            NaN
# 2                        NaN  7.381412e+04  45233226.0            NaN
# 3                        NaN  3.840584e+05  45232150.0           11.0
# 4                        NaN  7.790000e+06  45211000.0            6.0
# ...                      ...           ...         ...            ...
# 1380960                  NaN  5.000000e+05  92200000.0            2.0
# 1380961                  NaN  2.000000e+07  65111000.0            2.0
# 1380962                  NaN  4.984029e+06  85312110.0            3.0
# 1380963          497000000.0  4.970000e+08  65300000.0            1.0
# 1380964                  1.0  1.000000e+00  65310000.0            1.0
#
#         onBehalf  ... contractorSme numberTendersSme subContracted  gpa  \
# 0            NaN  ...           NaN              NaN           NaN    Y
# 1            NaN  ...           NaN              NaN           NaN    Y
# 2            NaN  ...           NaN              NaN           NaN    Y
# 3            NaN  ...           NaN              NaN           NaN    N
# 4            NaN  ...           NaN              NaN             N    N
# ...          ...  ...           ...              ...           ...  ...
# 1380960        N  ...             Y              NaN           NaN  NaN
# 1380961        N  ...             N              NaN           NaN  NaN
# 1380962        N  ...             N              NaN           NaN  NaN
# 1380963        N  ...         N---N              NaN           NaN  NaN
# 1380964        N  ...             N              NaN           NaN  NaN
#
#         multipleCae  typeOfContract topType  renewal contractDuration  \
# 0               NaN               W     OPE      NaN              NaN
# 1               NaN               W     OPE      NaN              NaN
# 2               NaN               W     OPE      NaN              NaN
# 3               NaN               W     OPE      NaN              NaN
# 4               NaN               W     RES      NaN            24.01
# ...             ...             ...     ...      ...              ...
# 1380960           N               S     NIC      NaN            96.00
# 1380961           N               S     NIC      NaN              NaN
# 1380962           N               S     NIC      NaN            60.00
# 1380963           N               S     NOC      NaN              NaN
# 1380964           N               S     NOC      NaN              NaN
#
#         publicityDuration
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                    36.0
# ...                   ...
# 1380960              35.0
# 1380961              62.0
# 1380962              35.0
# 1380963               NaN
# 1380964               NaN
#
# [1380965 rows x 26 columns]

# %% [markdown]
# # Attribut awardDate

# %%
awardDate = lots[['awardDate']]

# %%
awardDate
# Out:
#           awardDate
# 0        2009-09-24
# 1        2009-09-24
# 2        2009-09-24
# 3        2009-09-28
# 4        2009-11-06
# ...             ...
# 1380960  2020-12-28
# 1380961  2020-12-10
# 1380962  2020-12-17
# 1380963  2020-12-11
# 1380964  2020-12-23
#
# [1380965 rows x 1 columns]

# %%
awardDate = clean_awardDate(awardDate)

# %%
awardDate
# Out:
#          awardDate    cleaned
# 0       2009-09-24 2009-09-24
# 1       2009-09-24 2009-09-24
# 2       2009-09-24 2009-09-24
# 3       2009-09-28 2009-09-28
# 4       2009-11-06 2009-11-06
# ...            ...        ...
# 1380960 2020-12-28 2020-12-28
# 1380961 2020-12-10 2020-12-10
# 1380962 2020-12-17 2020-12-17
# 1380963 2020-12-11 2020-12-11
# 1380964 2020-12-23 2020-12-23
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'awardDate', 
    cleaned = awardDate['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut awardEstimatedPrice

# %%
awardEstimatedPrice = lots[['awardEstimatedPrice']]

# %%
awardEstimatedPrice
# Out:
#          awardEstimatedPrice
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1380960                  NaN
# 1380961                  NaN
# 1380962                  NaN
# 1380963          497000000.0
# 1380964                  1.0
#
# [1380965 rows x 1 columns]

# %%
awardEstimatedPrice = clean_awardEstimatedPrice(awardEstimatedPrice)

# %%
awardEstimatedPrice
# Out:
#          awardEstimatedPrice      cleaned
# 0                        NaN     100000.0
# 1                        NaN     100000.0
# 2                        NaN     100000.0
# 3                        NaN     100000.0
# 4                        NaN     100000.0
# ...                      ...          ...
# 1380960                  NaN     100000.0
# 1380961                  NaN     100000.0
# 1380962                  NaN     100000.0
# 1380963          497000000.0  497000000.0
# 1380964                  1.0          1.0
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'awardEstimatedPrice', 
    cleaned = awardEstimatedPrice['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut awardPrice

# %%
awardPrice = lots[['awardPrice']]

# %%
awardPrice
# Out:
#            awardPrice
# 0        8.916747e+05
# 1        1.169251e+05
# 2        7.381412e+04
# 3        3.840584e+05
# 4        7.790000e+06
# ...               ...
# 1380960  5.000000e+05
# 1380961  2.000000e+07
# 1380962  4.984029e+06
# 1380963  4.970000e+08
# 1380964  1.000000e+00
#
# [1380965 rows x 1 columns]

# %%
awardPrice = clean_awardPrice(awardPrice)

# %%
awardPrice
# Out:
#            awardPrice       cleaned
# 0        8.916747e+05  8.916747e+05
# 1        1.169251e+05  1.169251e+05
# 2        7.381412e+04  7.381412e+04
# 3        3.840584e+05  3.840584e+05
# 4        7.790000e+06  7.790000e+06
# ...               ...           ...
# 1380960  5.000000e+05  5.000000e+05
# 1380961  2.000000e+07  2.000000e+07
# 1380962  4.984029e+06  4.984029e+06
# 1380963  4.970000e+08  4.970000e+08
# 1380964  1.000000e+00  1.000000e+00
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'awardPrice', 
    cleaned = awardPrice['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut cpv

# %%
cpv = lots[['cpv']]

# %%
cpv
# Out:
#                 cpv
# 0        45233226.0
# 1        45233226.0
# 2        45233226.0
# 3        45232150.0
# 4        45211000.0
# ...             ...
# 1380960  92200000.0
# 1380961  65111000.0
# 1380962  85312110.0
# 1380963  65300000.0
# 1380964  65310000.0
#
# [1380965 rows x 1 columns]

# %%
cpv = clean_cpv(cpv)

# %%
cpv
# Out:
#                 cpv     cleaned
# 0        45233226.0  45233226.0
# 1        45233226.0  45233226.0
# 2        45233226.0  45233226.0
# 3        45232150.0  45232150.0
# 4        45211000.0  45211000.0
# ...             ...         ...
# 1380960  92200000.0  92200000.0
# 1380961  65111000.0  65111000.0
# 1380962  85312110.0  85312110.0
# 1380963  65300000.0  65300000.0
# 1380964  65310000.0  65310000.0
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'cpv', 
    cleaned = cpv['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut numberTenders

# %%
numberTenders = lots[['numberTenders']]

# %%
numberTenders
# Out:
#          numberTenders
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                 11.0
# 4                  6.0
# ...                ...
# 1380960            2.0
# 1380961            2.0
# 1380962            3.0
# 1380963            1.0
# 1380964            1.0
#
# [1380965 rows x 1 columns]

# %%
numberTenders  = clean_numberTenders(numberTenders)

# %%
numberTenders
# Out:
#          numberTenders  cleaned
# 0                  NaN      2.0
# 1                  NaN      2.0
# 2                  NaN      2.0
# 3                 11.0     11.0
# 4                  6.0      6.0
# ...                ...      ...
# 1380960            2.0      2.0
# 1380961            2.0      2.0
# 1380962            3.0      3.0
# 1380963            1.0      1.0
# 1380964            1.0      1.0
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'numberTenders', 
    cleaned = numberTenders['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut onBehalf

# %%
onBehalf = lots[['onBehalf']]

# %%
onBehalf
# Out:
#         onBehalf
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1380960        N
# 1380961        N
# 1380962        N
# 1380963        N
# 1380964        N
#
# [1380965 rows x 1 columns]

# %%
onBehalf  = clean_onBehalf(onBehalf)

# %%
onBehalf
# Out:
#         onBehalf cleaned
# 0            NaN       N
# 1            NaN       N
# 2            NaN       N
# 3            NaN       N
# 4            NaN       N
# ...          ...     ...
# 1380960        N       N
# 1380961        N       N
# 1380962        N       N
# 1380963        N       N
# 1380964        N       N
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'onBehalf', 
    cleaned = onBehalf['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut jointProcurement

# %%
jointProcurement = lots[['jointProcurement']]

# %%
jointProcurement
# Out:
#         jointProcurement
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1380960              NaN
# 1380961              NaN
# 1380962              NaN
# 1380963              NaN
# 1380964              NaN
#
# [1380965 rows x 1 columns]

# %%
jointProcurement  = clean_jointProcurement(jointProcurement)

# %%
jointProcurement
# Out:
#         jointProcurement cleaned
# 0                    NaN       N
# 1                    NaN       N
# 2                    NaN       N
# 3                    NaN       N
# 4                    NaN       N
# ...                  ...     ...
# 1380960              NaN       N
# 1380961              NaN       N
# 1380962              NaN       N
# 1380963              NaN       N
# 1380964              NaN       N
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'jointProcurement', 
    cleaned = jointProcurement['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut fraEstimated

# %%
fraEstimated = lots[['fraEstimated']]

# %%
fraEstimated
# Out:
#         fraEstimated
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1380960          NaN
# 1380961          NaN
# 1380962          NaN
# 1380963          NaN
# 1380964          NaN
#
# [1380965 rows x 1 columns]

# %%
fraEstimated  = clean_fraEstimated(fraEstimated)

# %%
fraEstimated
# Out:
#         fraEstimated cleaned
# 0                NaN       K
# 1                NaN       K
# 2                NaN       K
# 3                NaN       K
# 4                NaN       K
# ...              ...     ...
# 1380960          NaN       K
# 1380961          NaN       K
# 1380962          NaN       K
# 1380963          NaN       K
# 1380964          NaN       K
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'fraEstimated', 
    cleaned = fraEstimated['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut lotsNumber

# %%
lotsNumber = lots[['lotsNumber']]

# %%
lotsNumber
# Out:
#         lotsNumber
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1380960        NaN
# 1380961        NaN
# 1380962        NaN
# 1380963        NaN
# 1380964        NaN
#
# [1380965 rows x 1 columns]

# %%
lotsNumber  = clean_lotsNumber(lotsNumber)

# %%
lotsNumber
# Out:
#         lotsNumber cleaned
# 0              NaN       1
# 1              NaN       1
# 2              NaN       1
# 3              NaN       1
# 4              NaN       1
# ...            ...     ...
# 1380960        NaN       1
# 1380961        NaN       1
# 1380962        NaN       1
# 1380963        NaN       1
# 1380964        NaN       1
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'lotsNumber', 
    cleaned = lotsNumber['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut accelerated

# %%
accelerated = lots[['accelerated']]

# %%
accelerated
# Out:
#         accelerated
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1380960         NaN
# 1380961         NaN
# 1380962         NaN
# 1380963         NaN
# 1380964         NaN
#
# [1380965 rows x 1 columns]

# %%
accelerated  = clean_accelerated(accelerated)

# %%
accelerated
# Out:
#         accelerated cleaned
# 0               NaN       N
# 1               NaN       N
# 2               NaN       N
# 3               NaN       N
# 4               NaN       N
# ...             ...     ...
# 1380960         NaN       N
# 1380961         NaN       N
# 1380962         NaN       N
# 1380963         NaN       N
# 1380964         NaN       N
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'accelerated', 
    cleaned = accelerated['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut contractorSme

# %%
contractorSme = lots[['contractorSme']]

# %%
contractorSme
# Out:
#         contractorSme
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1380960             Y
# 1380961             N
# 1380962             N
# 1380963         N---N
# 1380964             N
#
# [1380965 rows x 1 columns]

# %%
contractorSme  = clean_contractorSme(contractorSme)

# %%
contractorSme
# Out:
#         contractorSme cleaned
# 0                 NaN       N
# 1                 NaN       N
# 2                 NaN       N
# 3                 NaN       N
# 4                 NaN       N
# ...               ...     ...
# 1380960             Y       Y
# 1380961             N       N
# 1380962             N       N
# 1380963         N---N       N
# 1380964             N       N
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'contractorSme', 
    cleaned = contractorSme['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut numberTendersSme

# %%
numberTendersSme = lots[['numberTendersSme']]

# %%
numberTendersSme
# Out:
#          numberTendersSme
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1380960               NaN
# 1380961               NaN
# 1380962               NaN
# 1380963               NaN
# 1380964               NaN
#
# [1380965 rows x 1 columns]

# %%
numberTendersSme  = clean_numberTendersSme(numberTendersSme)

# %%
numberTendersSme
# Out:
#          numberTendersSme  cleaned
# 0                     NaN      1.0
# 1                     NaN      1.0
# 2                     NaN      1.0
# 3                     NaN      1.0
# 4                     NaN      1.0
# ...                   ...      ...
# 1380960               NaN      1.0
# 1380961               NaN      1.0
# 1380962               NaN      1.0
# 1380963               NaN      1.0
# 1380964               NaN      1.0
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'numberTendersSme', 
    cleaned = numberTendersSme['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut subContracted

# %%
subContracted = lots[['subContracted']]

# %%
subContracted
# Out:
#         subContracted
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                   N
# ...               ...
# 1380960           NaN
# 1380961           NaN
# 1380962           NaN
# 1380963           NaN
# 1380964           NaN
#
# [1380965 rows x 1 columns]

# %%
subContracted  = clean_subContracted(subContracted)

# %%
subContracted
# Out:
#         subContracted cleaned
# 0                 NaN       N
# 1                 NaN       N
# 2                 NaN       N
# 3                 NaN       N
# 4                   N       N
# ...               ...     ...
# 1380960           NaN       N
# 1380961           NaN       N
# 1380962           NaN       N
# 1380963           NaN       N
# 1380964           NaN       N
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'subContracted', 
    cleaned = subContracted['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut gpa

# %%
gpa = lots[['gpa']]

# %%
gpa
# Out:
#          gpa
# 0          Y
# 1          Y
# 2          Y
# 3          N
# 4          N
# ...      ...
# 1380960  NaN
# 1380961  NaN
# 1380962  NaN
# 1380963  NaN
# 1380964  NaN
#
# [1380965 rows x 1 columns]

# %%
gpa  = clean_gpa(gpa)

# %%
gpa
# Out:
#          gpa cleaned
# 0          Y       Y
# 1          Y       Y
# 2          Y       Y
# 3          N       N
# 4          N       N
# ...      ...     ...
# 1380960  NaN       Y
# 1380961  NaN       Y
# 1380962  NaN       Y
# 1380963  NaN       Y
# 1380964  NaN       Y
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'gpa', 
    cleaned = gpa['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut multipleCae

# %%
multipleCae = lots[['multipleCae']]

# %%
multipleCae
# Out:
#         multipleCae
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1380960           N
# 1380961           N
# 1380962           N
# 1380963           N
# 1380964           N
#
# [1380965 rows x 1 columns]

# %%
multipleCae  = clean_multipleCae(multipleCae)

# %%
multipleCae
# Out:
#         multipleCae cleaned
# 0               NaN       N
# 1               NaN       N
# 2               NaN       N
# 3               NaN       N
# 4               NaN       N
# ...             ...     ...
# 1380960           N       N
# 1380961           N       N
# 1380962           N       N
# 1380963           N       N
# 1380964           N       N
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'multipleCae', 
    cleaned = multipleCae['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut topType

# %%
topType = lots[['topType']]

# %%
topType
# Out:
#         topType
# 0           OPE
# 1           OPE
# 2           OPE
# 3           OPE
# 4           RES
# ...         ...
# 1380960     NIC
# 1380961     NIC
# 1380962     NIC
# 1380963     NOC
# 1380964     NOC
#
# [1380965 rows x 1 columns]

# %%
topType  = clean_topType(topType)

# %%
topType
# Out:
#         topType cleaned
# 0           OPE     OPE
# 1           OPE     OPE
# 2           OPE     OPE
# 3           OPE     OPE
# 4           RES     RES
# ...         ...     ...
# 1380960     NIC     NIC
# 1380961     NIC     NIC
# 1380962     NIC     NIC
# 1380963     NOC     NOC
# 1380964     NOC     NOC
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'topType', 
    cleaned = topType['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut renewal

# %%
renewal = lots[['renewal']]

# %%
renewal
# Out:
#         renewal
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1380960     NaN
# 1380961     NaN
# 1380962     NaN
# 1380963     NaN
# 1380964     NaN
#
# [1380965 rows x 1 columns]

# %%
renewal  = clean_renewal(renewal)

# %%
renewal
# Out:
#         renewal cleaned
# 0           NaN       Y
# 1           NaN       Y
# 2           NaN       Y
# 3           NaN       Y
# 4           NaN       Y
# ...         ...     ...
# 1380960     NaN       Y
# 1380961     NaN       Y
# 1380962     NaN       Y
# 1380963     NaN       Y
# 1380964     NaN       Y
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'renewal', 
    cleaned = renewal['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut contractDuration

# %%
contractDuration = lots[['contractDuration']]

# %%
contractDuration
# Out:
#          contractDuration
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                   24.01
# ...                   ...
# 1380960             96.00
# 1380961               NaN
# 1380962             60.00
# 1380963               NaN
# 1380964               NaN
#
# [1380965 rows x 1 columns]

# %%
contractDuration  = clean_contractDuration(contractDuration)

# %%
contractDuration
# Out:
#          contractDuration  cleaned
# 0                     NaN    24.00
# 1                     NaN    24.00
# 2                     NaN    24.00
# 3                     NaN    24.00
# 4                   24.01    24.01
# ...                   ...      ...
# 1380960             96.00    96.00
# 1380961               NaN    24.00
# 1380962             60.00    60.00
# 1380963               NaN    24.00
# 1380964               NaN    24.00
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'contractDuration', 
    cleaned = contractDuration['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %% [markdown]
# # Attribut publicityDuration

# %%
publicityDuration = lots[['publicityDuration']]

# %%
publicityDuration
# Out:
#          publicityDuration
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                     36.0
# ...                    ...
# 1380960               35.0
# 1380961               62.0
# 1380962               35.0
# 1380963                NaN
# 1380964                NaN
#
# [1380965 rows x 1 columns]

# %%
publicityDuration  = clean_publicityDuration(publicityDuration)

# %%
publicityDuration
# Out:
#          publicityDuration  cleaned
# 0                      NaN     42.0
# 1                      NaN     42.0
# 2                      NaN     42.0
# 3                      NaN     42.0
# 4                     36.0     36.0
# ...                    ...      ...
# 1380960               35.0     35.0
# 1380961               62.0     62.0
# 1380962               35.0     35.0
# 1380963                NaN     42.0
# 1380964                NaN     42.0
#
# [1380965 rows x 2 columns]

# %%
lots = replace_original_with_cleaned(
    original = lots, 
    column = 'publicityDuration', 
    cleaned = publicityDuration['cleaned'].values, 
    path = '../donnees/lots_cleaned.csv'
)

# %%
lots
# Out:
#            lotId    tedCanId  correctionsNb  cancelled  awardDate  \
# 0              0     2010142              0          0 2009-09-24
# 1              1     2010142              0          0 2009-09-24
# 2              2     2010142              0          0 2009-09-24
# 3              3     2010143              0          0 2009-09-28
# 4              4     2010144              0          0 2009-11-06
# ...          ...         ...            ...        ...        ...
# 1380960  1380960  2020643360              0          0 2020-12-28
# 1380961  1380961  2020643361              0          0 2020-12-10
# 1380962  1380962  2020643362              0          0 2020-12-17
# 1380963  1380963  2020643363              0          0 2020-12-11
# 1380964  1380964  2020643364              0          0 2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                   100000.0  8.916747e+05  45233226.0            2.0
# 1                   100000.0  1.169251e+05  45233226.0            2.0
# 2                   100000.0  7.381412e+04  45233226.0            2.0
# 3                   100000.0  3.840584e+05  45232150.0           11.0
# 4                   100000.0  7.790000e+06  45211000.0            6.0
# ...                      ...           ...         ...            ...
# 1380960             100000.0  5.000000e+05  92200000.0            2.0
# 1380961             100000.0  2.000000e+07  65111000.0            2.0
# 1380962             100000.0  4.984029e+06  85312110.0            3.0
# 1380963          497000000.0  4.970000e+08  65300000.0            1.0
# 1380964                  1.0  1.000000e+00  65310000.0            1.0
#
#         onBehalf  ... contractorSme numberTendersSme subContracted gpa  \
# 0              N  ...             N              1.0             N   Y
# 1              N  ...             N              1.0             N   Y
# 2              N  ...             N              1.0             N   Y
# 3              N  ...             N              1.0             N   N
# 4              N  ...             N              1.0             N   N
# ...          ...  ...           ...              ...           ...  ..
# 1380960        N  ...             Y              1.0             N   Y
# 1380961        N  ...             N              1.0             N   Y
# 1380962        N  ...             N              1.0             N   Y
# 1380963        N  ...             N              1.0             N   Y
# 1380964        N  ...             N              1.0             N   Y
#
#         multipleCae  typeOfContract topType  renewal contractDuration  \
# 0                 N               W     OPE        Y            24.00
# 1                 N               W     OPE        Y            24.00
# 2                 N               W     OPE        Y            24.00
# 3                 N               W     OPE        Y            24.00
# 4                 N               W     RES        Y            24.01
# ...             ...             ...     ...      ...              ...
# 1380960           N               S     NIC        Y            96.00
# 1380961           N               S     NIC        Y            24.00
# 1380962           N               S     NIC        Y            60.00
# 1380963           N               S     NOC        Y            24.00
# 1380964           N               S     NOC        Y            24.00
#
#         publicityDuration
# 0                    42.0
# 1                    42.0
# 2                    42.0
# 3                    42.0
# 4                    36.0
# ...                   ...
# 1380960              35.0
# 1380961              62.0
# 1380962              35.0
# 1380963              42.0
# 1380964              42.0
#
# [1380965 rows x 26 columns]
