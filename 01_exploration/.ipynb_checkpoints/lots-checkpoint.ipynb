# %%
from functions.utils_lots import *
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Les attributs

# %%
lots = load_data(path='../donnees/Lots.csv')

# %%
lots
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 0              0     2010142              0          0  2009-09-24
# 1              1     2010142              0          0  2009-09-24
# 2              2     2010142              0          0  2009-09-24
# 3              3     2010143              0          0  2009-09-28
# 4              4     2010144              0          0  2009-11-06
# ...          ...         ...            ...        ...         ...
# 1380960  1380960  2020643360              0          0  2020-12-28
# 1380961  1380961  2020643361              0          0  2020-12-10
# 1380962  1380962  2020643362              0          0  2020-12-17
# 1380963  1380963  2020643363              0          0  2020-12-11
# 1380964  1380964  2020643364              0          0  2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                        NaN  8.916747e+05  45233226.0            NaN
# 1                        NaN  1.169251e+05  45233226.0            NaN
# 2                        NaN  7.381412e+04  45233226.0            NaN
# 3                        NaN  3.840584e+05  45232150.0           11.0
# 4                        NaN  7.790000e+06  45211000.0            6.0
# ...                      ...           ...         ...            ...
# 1380960                  NaN  5.000000e+05  92200000.0            2.0
# 1380961                  NaN  2.000000e+07  65111000.0            2.0
# 1380962                  NaN  4.984029e+06  85312110.0            3.0
# 1380963          497000000.0  4.970000e+08  65300000.0            1.0
# 1380964                  1.0  1.000000e+00  65310000.0            1.0
#
#         onBehalf  ... contractorSme numberTendersSme subContracted  gpa  \
# 0            NaN  ...           NaN              NaN           NaN    Y
# 1            NaN  ...           NaN              NaN           NaN    Y
# 2            NaN  ...           NaN              NaN           NaN    Y
# 3            NaN  ...           NaN              NaN           NaN    N
# 4            NaN  ...           NaN              NaN             N    N
# ...          ...  ...           ...              ...           ...  ...
# 1380960        N  ...             Y              NaN           NaN  NaN
# 1380961        N  ...             N              NaN           NaN  NaN
# 1380962        N  ...             N              NaN           NaN  NaN
# 1380963        N  ...         N---N              NaN           NaN  NaN
# 1380964        N  ...             N              NaN           NaN  NaN
#
#         multipleCae  typeOfContract topType  renewal contractDuration  \
# 0               NaN               W     OPE      NaN              NaN
# 1               NaN               W     OPE      NaN              NaN
# 2               NaN               W     OPE      NaN              NaN
# 3               NaN               W     OPE      NaN              NaN
# 4               NaN               W     RES      NaN            24.01
# ...             ...             ...     ...      ...              ...
# 1380960           N               S     NIC      NaN            96.00
# 1380961           N               S     NIC      NaN              NaN
# 1380962           N               S     NIC      NaN            60.00
# 1380963           N               S     NOC      NaN              NaN
# 1380964           N               S     NOC      NaN              NaN
#
#         publicityDuration
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                    36.0
# ...                   ...
# 1380960              35.0
# 1380961              62.0
# 1380962              35.0
# 1380963               NaN
# 1380964               NaN
#
# [1380965 rows x 26 columns]

# %%
lot_dtypes = get_dtypes(lots)

# %%
lot_dtypes
# Out:
#                attribut     type
# 0                 lotId    int64
# 1              tedCanId    int64
# 2         correctionsNb    int64
# 3             cancelled    int64
# 4             awardDate   object
# 5   awardEstimatedPrice  float64
# 6            awardPrice  float64
# 7                   cpv  float64
# 8         numberTenders  float64
# 9              onBehalf   object
# 10     jointProcurement   object
# 11         fraAgreement   object
# 12         fraEstimated   object
# 13           lotsNumber   object
# 14          accelerated   object
# 15      outOfDirectives    int64
# 16        contractorSme   object
# 17     numberTendersSme  float64
# 18        subContracted   object
# 19                  gpa   object
# 20          multipleCae   object
# 21       typeOfContract   object
# 22              topType   object
# 23              renewal   object
# 24     contractDuration  float64
# 25    publicityDuration  float64

# %% [markdown]
# # Attribut lotId

# %%
lotId = lots[['lotId']]

# %%
lotId
# Out:
#            lotId
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 1380960  1380960
# 1380961  1380961
# 1380962  1380962
# 1380963  1380963
# 1380964  1380964
#
# [1380965 rows x 1 columns]

# %%
lotId_vc = get_vc(lots, column='lotId')

# %%
lotId_vc
# Out:
#           valeur  count  proportion
# 0              0      1    0.000072
# 1         920641      1    0.000072
# 2         920649      1    0.000072
# 3         920648      1    0.000072
# 4         920647      1    0.000072
# ...          ...    ...         ...
# 1380960   460320      1    0.000072
# 1380961   460319      1    0.000072
# 1380962   460318      1    0.000072
# 1380963   460317      1    0.000072
# 1380964  1380964      1    0.000072
#
# [1380965 rows x 3 columns]

# %%
lotId_na = get_na(lots, column='lotId')

# %%
lotId_na
# Out:
#   attribut    count  proportion
# 0   manque        0         0.0
# 1    exist  1380965       100.0

# %% [markdown]
# # Attribut tedCanId

# %%
tedCanId = lots[['tedCanId']]

# %%
tedCanId
# Out:
#            tedCanId
# 0           2010142
# 1           2010142
# 2           2010142
# 3           2010143
# 4           2010144
# ...             ...
# 1380960  2020643360
# 1380961  2020643361
# 1380962  2020643362
# 1380963  2020643363
# 1380964  2020643364
#
# [1380965 rows x 1 columns]

# %%
tedCanId_vc = get_vc(lots, column='tedCanId')

# %%
tedCanId_vc
# Out:
#             valeur  count  proportion
# 0       2014304772    883    0.063941
# 1       2012153095    878    0.063579
# 2       2019505633    868    0.062855
# 3       2015214049    867    0.062782
# 4       2011362866    787    0.056989
# ...            ...    ...         ...
# 410278  2014177392      1    0.000072
# 410279  2014177391      1    0.000072
# 410280  2014177390      1    0.000072
# 410281  2014177370      1    0.000072
# 410282  2020643364      1    0.000072
#
# [410283 rows x 3 columns]

# %%
tedCanId_na = get_na(lots, column='tedCanId')

# %%
tedCanId_na
# Out:
#   attribut    count  proportion
# 0   manque        0         0.0
# 1    exist  1380965       100.0

# %% [markdown]
# # Attribut correctionsNb

# %%
correctionsNb = lots[['correctionsNb']]

# %%
correctionsNb
# Out:
#          correctionsNb
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 1380960              0
# 1380961              0
# 1380962              0
# 1380963              0
# 1380964              0
#
# [1380965 rows x 1 columns]

# %%
correctionsNb_vc = get_vc(lots, column='correctionsNb')

# %%
correctionsNb_vc
# Out:
#    valeur    count  proportion
# 0       0  1375786   99.624972
# 1       1     5089    0.368510
# 2       2       90    0.006517

# %%
correctionsNb_na = get_na(lots, column='correctionsNb')

# %%
correctionsNb_na
# Out:
#   attribut    count  proportion
# 0   manque        0         0.0
# 1    exist  1380965       100.0

# %% [markdown]
# # Attribut cancelled

# %%
cancelled = lots[['cancelled']]

# %%
cancelled
# Out:
#          cancelled
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 1380960          0
# 1380961          0
# 1380962          0
# 1380963          0
# 1380964          0
#
# [1380965 rows x 1 columns]

# %%
cancelled_vc = get_vc(lots, column='cancelled')

# %%
cancelled_vc
# Out:
#    valeur    count  proportion
# 0       0  1380685   99.979724
# 1       1      280    0.020276

# %%
cancelled_na = get_na(lots, column='cancelled')

# %%
cancelled_na
# Out:
#   attribut    count  proportion
# 0   manque        0         0.0
# 1    exist  1380965       100.0

# %% [markdown]
# # Attribut awardDate

# %%
awardDate = lots[['awardDate']]

# %%
awardDate
# Out:
#           awardDate
# 0        2009-09-24
# 1        2009-09-24
# 2        2009-09-24
# 3        2009-09-28
# 4        2009-11-06
# ...             ...
# 1380960  2020-12-28
# 1380961  2020-12-10
# 1380962  2020-12-17
# 1380963  2020-12-11
# 1380964  2020-12-23
#
# [1380965 rows x 1 columns]

# %%
awardDate_vc = get_vc(lots, column='awardDate')

# %%
awardDate_vc
# Out:
#           valeur  count  proportion
# 0     2012-01-01   1866    0.156243
# 1     2011-01-01   1675    0.140250
# 2     2010-01-01   1634    0.136817
# 3     2010-01-04   1386    0.116052
# 4     2019-12-18   1310    0.109688
# ...          ...    ...         ...
# 4367  2010-07-04      1    0.000084
# 4368  2006-12-21      1    0.000084
# 4369  2012-10-07      1    0.000084
# 4370  2001-01-04      1    0.000084
# 4371  2006-07-26      1    0.000084
#
# [4372 rows x 3 columns]

# %%
awardDate_na = get_na(lots, column='awardDate')

# %%
awardDate_na
# Out:
#   attribut    count  proportion
# 0   manque   186671   13.517432
# 1    exist  1194294   86.482568

# %%
plot_proportion(
    data=awardDate_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs awardDate', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_awardDate_01.png',
    logy=False
)

# %%
awardDate_cat = categorized_awardDate(awardDate)

# %%
awardDate_cat
# Out:
#          awardDate    year     category
# 0       2009-09-24  2009.0       < 2010
# 1       2009-09-24  2009.0       < 2010
# 2       2009-09-24  2009.0       < 2010
# 3       2009-09-28  2009.0       < 2010
# 4       2009-11-06  2009.0       < 2010
# ...            ...     ...          ...
# 1380960 2020-12-28  2020.0  [2010-2020]
# 1380961 2020-12-10  2020.0  [2010-2020]
# 1380962 2020-12-17  2020.0  [2010-2020]
# 1380963 2020-12-11  2020.0  [2010-2020]
# 1380964 2020-12-23  2020.0  [2010-2020]
#
# [1380965 rows x 3 columns]

# %%
awardDate_cat_vc = get_vc(awardDate_cat, column='category')

# %%
awardDate_cat_vc
# Out:
#         valeur    count  proportion
# 0  [2010-2020]  1167570   84.547400
# 1      missing   186671   13.517432
# 2       < 2010    26721    1.934951
# 3       > 2020        3    0.000217

# %%
plot_proportion(
    data=awardDate_cat_vc,
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs awardDate', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_awardDate_02.png',
    logy=True
)

# %% [markdown]
# # Attribut awardEstimatedPrice

# %%
awardEstimatedPrice = lots[['awardEstimatedPrice']]

# %%
awardEstimatedPrice
# Out:
#          awardEstimatedPrice
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1380960                  NaN
# 1380961                  NaN
# 1380962                  NaN
# 1380963          497000000.0
# 1380964                  1.0
#
# [1380965 rows x 1 columns]

# %%
awardEstimatedPrice_vc = get_vc(lots, column='awardEstimatedPrice')

# %%
awardEstimatedPrice_vc
# Out:
#              valeur  count  proportion
# 0      2.000000e+05   2415    1.273647
# 1      1.000000e+05   2135    1.125978
# 2      4.000000e+05   1911    1.007842
# 3      4.000000e+04   1775    0.936117
# 4      5.000000e+04   1712    0.902892
# ...             ...    ...         ...
# 78360  4.107470e+05      1    0.000527
# 78361  2.124253e+06      1    0.000527
# 78362  8.587725e+06      1    0.000527
# 78363  4.125370e+03      1    0.000527
# 78364  4.970000e+08      1    0.000527
#
# [78365 rows x 3 columns]

# %%
awardEstimatedPrice_na = get_na(lots, column='awardEstimatedPrice')

# %%
awardEstimatedPrice_na
# Out:
#   attribut    count  proportion
# 0   manque  1191352   86.269529
# 1    exist   189613   13.730471

# %%
plot_proportion(
    data=awardEstimatedPrice_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de awardEstimatedPrice', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_awardEstimatedPrice_01.png',
    logy=False
)

# %%
awardEstimatedPrice_cat = categorized_awardEstimatedPrice(awardEstimatedPrice)

# %%
awardEstimatedPrice_cat
# Out:
#          awardEstimatedPrice category
# 0                        NaN  missing
# 1                        NaN  missing
# 2                        NaN  missing
# 3                        NaN  missing
# 4                        NaN  missing
# ...                      ...      ...
# 1380960                  NaN  missing
# 1380961                  NaN  missing
# 1380962                  NaN  missing
# 1380963          497000000.0  correct
# 1380964                  1.0      ≤ 1
#
# [1380965 rows x 2 columns]

# %%
awardEstimatedPrice_cat_vc = get_vc(awardEstimatedPrice_cat, column='category')

# %%
awardEstimatedPrice_cat_vc
# Out:
#        valeur    count  proportion
# 0     missing  1191352   86.269529
# 1     correct   188116   13.622069
# 2         ≤ 1     1117    0.080885
# 3  repetition      380    0.027517

# %%
plot_proportion(
    data=awardEstimatedPrice_cat_vc,
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs awardEstimatedPrice', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_awardEstimatedPrice_02.png',
    logy=True
)

# %% [markdown]
# # Attribut awardPrice

# %%
awardPrice = lots[['awardPrice']]

# %%
awardPrice
# Out:
#            awardPrice
# 0        8.916747e+05
# 1        1.169251e+05
# 2        7.381412e+04
# 3        3.840584e+05
# 4        7.790000e+06
# ...               ...
# 1380960  5.000000e+05
# 1380961  2.000000e+07
# 1380962  4.984029e+06
# 1380963  4.970000e+08
# 1380964  1.000000e+00
#
# [1380965 rows x 1 columns]

# %%
awardPrice_vc = get_vc(lots, column='awardPrice')

# %%
awardPrice_vc
# Out:
#               valeur  count  proportion
# 0       0.000000e+00  60518    6.339340
# 1       1.000000e+00  16662    1.745366
# 2       2.000000e+05   6156    0.644849
# 3       1.000000e+05   5652    0.592054
# 4       4.000000e+05   4624    0.484370
# ...              ...    ...         ...
# 466015  1.481150e+03      1    0.000105
# 466016  9.697200e+03      1    0.000105
# 466017  1.348770e+04      1    0.000105
# 466018  3.216600e+03      1    0.000105
# 466019  4.970000e+08      1    0.000105
#
# [466020 rows x 3 columns]

# %%
awardPrice_na = get_na(lots, column='awardPrice')

# %%
awardPrice_na
# Out:
#   attribut   count  proportion
# 0   manque  426323   30.871383
# 1    exist  954642   69.128617

# %%
plot_proportion(
    data=awardPrice_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de awardPrice', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_awardPrice_01.png',
    logy=False
)

# %%
awardPrice_cat = categorized_awardPrice(awardPrice)

# %%
awardPrice_cat
# Out:
#            awardPrice category
# 0        8.916747e+05  correct
# 1        1.169251e+05  correct
# 2        7.381412e+04  correct
# 3        3.840584e+05  correct
# 4        7.790000e+06  correct
# ...               ...      ...
# 1380960  5.000000e+05  correct
# 1380961  2.000000e+07  correct
# 1380962  4.984029e+06  correct
# 1380963  4.970000e+08  correct
# 1380964  1.000000e+00      ≤ 1
#
# [1380965 rows x 2 columns]

# %%
awardPrice_cat_vc = get_vc(awardPrice_cat, column='category')

# %%
awardPrice_cat_vc
# Out:
#        valeur   count  proportion
# 0     correct  874903   63.354466
# 1     missing  426323   30.871383
# 2         ≤ 1   77443    5.607890
# 3  repetition    2296    0.166261

# %%
plot_proportion(
    data=awardPrice_cat_vc,
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs awardPrice', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_awardPrice_02.png',
    logy=True
)

# %% [markdown]
# # Attribut cpv

# %%
cpv = lots[['cpv']]

# %%
cpv
# Out:
#                 cpv
# 0        45233226.0
# 1        45233226.0
# 2        45233226.0
# 3        45232150.0
# 4        45211000.0
# ...             ...
# 1380960  92200000.0
# 1380961  65111000.0
# 1380962  85312110.0
# 1380963  65300000.0
# 1380964  65310000.0
#
# [1380965 rows x 1 columns]

# %%
cpv_vc = get_vc(lots, column='cpv')

# %%
cpv_vc
# Out:
#           valeur  count  proportion
# 0     45000000.0  61364    4.443788
# 1     15800000.0  26638    1.929040
# 2     15000000.0  25823    1.870020
# 3     80530000.0  25800    1.868355
# 4     33600000.0  24926    1.805063
# ...          ...    ...         ...
# 6253  31521330.0      1    0.000072
# 6254  35341100.0      1    0.000072
# 6255  15812200.0      1    0.000072
# 6256  45213341.0      1    0.000072
# 6257  38821000.0      1    0.000072
#
# [6258 rows x 3 columns]

# %%
cpv_na = get_na(lots, column='cpv')

# %%
cpv_na
# Out:
#   attribut    count  proportion
# 0   manque       71    0.005141
# 1    exist  1380894   99.994859

# %%
plot_proportion(
    data=cpv_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de cpv', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_cpv_01.png',
    logy=True
)

# %% [markdown]
# # Attribut numberTenders

# %%
numberTenders = lots[['numberTenders']]

# %%
numberTenders
# Out:
#          numberTenders
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                 11.0
# 4                  6.0
# ...                ...
# 1380960            2.0
# 1380961            2.0
# 1380962            3.0
# 1380963            1.0
# 1380964            1.0
#
# [1380965 rows x 1 columns]

# %%
numberTenders_vc = get_vc(lots, column='numberTenders')

# %%
numberTenders_vc
# Out:
#      valeur   count  proportion
# 0       2.0  174030   18.187500
# 1       3.0  167128   17.466186
# 2       1.0  151923   15.877145
# 3       4.0  129149   13.497083
# 4       5.0   89056    9.307050
# ..      ...     ...         ...
# 214   205.0       1    0.000105
# 215   170.0       1    0.000105
# 216   268.0       1    0.000105
# 217   688.0       1    0.000105
# 218   157.0       1    0.000105
#
# [219 rows x 3 columns]

# %%
numberTenders_na = get_na(lots, column='numberTenders')

# %%
numberTenders_na
# Out:
#   attribut   count  proportion
# 0   manque  424099   30.710337
# 1    exist  956866   69.289663

# %%
plot_proportion(
    data=numberTenders_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de numberTenders', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_numberTenders_01.png',
    logy=False
)

# %% [markdown]
# # Attribut onBehalf

# %%
onBehalf = lots[['onBehalf']]

# %%
onBehalf
# Out:
#         onBehalf
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1380960        N
# 1380961        N
# 1380962        N
# 1380963        N
# 1380964        N
#
# [1380965 rows x 1 columns]

# %%
onBehalf_vc = get_vc(lots, column='onBehalf')

# %%
onBehalf_vc
# Out:
#   valeur    count  proportion
# 0      N  1004753   91.472403
# 1      Y    93669    8.527597

# %%
onBehalf_na = get_na(lots, column='onBehalf')

# %%
onBehalf_na
# Out:
#   attribut    count  proportion
# 0   manque   282543   20.459823
# 1    exist  1098422   79.540177

# %%
plot_proportion(
    data=onBehalf_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de onBehalf', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_onBehalf_01.png',
    logy=False
)

# %% [markdown]
# # Attribut jointProcurement

# %%
jointProcurement = lots[['jointProcurement']]

# %%
jointProcurement
# Out:
#         jointProcurement
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1380960              NaN
# 1380961              NaN
# 1380962              NaN
# 1380963              NaN
# 1380964              NaN
#
# [1380965 rows x 1 columns]

# %%
jointProcurement_vc = get_vc(lots, column='jointProcurement')

# %%
jointProcurement_vc
# Out:
#   valeur   count  proportion
# 0      N  504113    93.56999
# 1      Y   34642     6.43001

# %%
jointProcurement_na = get_na(lots, column='jointProcurement')

# %%
jointProcurement_na
# Out:
#   attribut   count  proportion
# 0   manque  842210   60.987063
# 1    exist  538755   39.012937

# %%
plot_proportion(
    data=jointProcurement_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de jointProcurement', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_jointProcurement_01.png',
    logy=False
)

# %% [markdown]
# # Attribut fraAgreement

# %%
fraAgreement = lots[['fraAgreement']]

# %%
fraAgreement
# Out:
#         fraAgreement
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  Y
# ...              ...
# 1380960            N
# 1380961            N
# 1380962            N
# 1380963            N
# 1380964            N
#
# [1380965 rows x 1 columns]

# %%
fraAgreement_vc = get_vc(lots, column='fraAgreement')

# %%
fraAgreement_vc
# Out:
#   valeur   count  proportion
# 0      N  899503   65.135829
# 1      Y  481462   34.864171

# %%
fraAgreement_na = get_na(lots, column='fraAgreement')

# %%
fraAgreement_na
# Out:
#   attribut    count  proportion
# 0   manque        0         0.0
# 1    exist  1380965       100.0

# %% [markdown]
# # Attribut fraEstimated

# %%
fraEstimated = lots[['fraEstimated']]

# %%
fraEstimated
# Out:
#         fraEstimated
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1380960          NaN
# 1380961          NaN
# 1380962          NaN
# 1380963          NaN
# 1380964          NaN
#
# [1380965 rows x 1 columns]

# %%
fraEstimated_vc = get_vc(lots, column='fraEstimated')

# %%
fraEstimated_vc
# Out:
#   valeur  count  proportion
# 0      K  73061   30.606594
# 1      A  65544   27.457585
# 2      C  65021   27.238490
# 3     KA  20307    8.506975
# 4     AC   8893    3.725441
# 5     KC   3363    1.408822
# 6    KAC   2521    1.056093

# %%
fraEstimated_na = get_na(lots, column='fraEstimated')

# %%
fraEstimated_na
# Out:
#   attribut    count  proportion
# 0   manque  1142255   82.714261
# 1    exist   238710   17.285739

# %%
plot_proportion(
    data=fraEstimated_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de fraEstimated', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_fraEstimated_01.png',
    logy=False
)

# %% [markdown]
# # Attribut lotsNumber

# %%
lotsNumber = lots[['lotsNumber']]

# %%
lotsNumber
# Out:
#         lotsNumber
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1380960        NaN
# 1380961        NaN
# 1380962        NaN
# 1380963        NaN
# 1380964        NaN
#
# [1380965 rows x 1 columns]

# %%
lotsNumber_vc = get_vc(lots, column='lotsNumber')

# %%
lotsNumber_vc
# Out:
#        valeur   count  proportion
# 0           1  211722   19.503895
# 1           2  158022   14.557035
# 2           3  107122    9.868111
# 3           4   77902    7.176356
# 4           5   58815    5.418056
# ...       ...     ...         ...
# 12814   6GP01       1    0.000092
# 12815  19GP01       1    0.000092
# 12816   1GP15       1    0.000092
# 12817   2GP15       1    0.000092
# 12818   5.2.B       1    0.000092
#
# [12819 rows x 3 columns]

# %%
lotsNumber_na = get_na(lots, column='lotsNumber')

# %%
lotsNumber_na
# Out:
#   attribut    count  proportion
# 0   manque   295428   21.392867
# 1    exist  1085537   78.607133

# %%
plot_proportion(
    data=lotsNumber_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de lotsNumber', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_lotsNumber_01.png',
    logy=False
)

# %%
lotsNumber_cat = categorized_lotNumber(lotsNumber)

# %%
lotsNumber_cat
# Out:
#         lotsNumber category
# 0              NaN  missing
# 1              NaN  missing
# 2              NaN  missing
# 3              NaN  missing
# 4              NaN  missing
# ...            ...      ...
# 1380960        NaN  missing
# 1380961        NaN  missing
# 1380962        NaN  missing
# 1380963        NaN  missing
# 1380964        NaN  missing
#
# [1380965 rows x 2 columns]

# %%
lotsNumber_cat_vc = get_vc(lotsNumber, column='category')

# %%
lotsNumber_cat_vc
# Out:
#         valeur    count  proportion
# 0      correct  1068827   77.397110
# 1      missing   295428   21.392867
# 2  not numeric    16710    1.210023

# %%
plot_proportion(
    data=lotsNumber_cat_vc,
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs lotsNumber', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_lotsNumber_02.png',
    logy=True
)

# %% [markdown]
# # Attribut accelerated

# %%
accelerated = lots[['accelerated']]

# %%
accelerated
# Out:
#         accelerated
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1380960         NaN
# 1380961         NaN
# 1380962         NaN
# 1380963         NaN
# 1380964         NaN
#
# [1380965 rows x 1 columns]

# %%
accelerated_vc = get_vc(lots, column='accelerated')

# %%
accelerated_vc
# Out:
#   valeur  count  proportion
# 0      Y   2555       100.0

# %%
accelerated_na = get_na(lots, column='accelerated')

# %%
accelerated_na
# Out:
#   attribut    count  proportion
# 0   manque  1378410   99.814984
# 1    exist     2555    0.185016

# %%
plot_proportion(
    data=accelerated_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de accelerated', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_accelerated_01.png',
    logy=True
)

# %% [markdown]
# # Attribut outOfDirectives

# %%
outOfDirectives = lots[['outOfDirectives']]

# %%
outOfDirectives
# Out:
#          outOfDirectives
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 1380960                0
# 1380961                0
# 1380962                0
# 1380963                0
# 1380964                0
#
# [1380965 rows x 1 columns]

# %%
outOfDirectives_vc = get_vc(lots, column='outOfDirectives')

# %%
outOfDirectives_vc
# Out:
#    valeur    count  proportion
# 0       0  1325454   95.980275
# 1       1    55511    4.019725

# %%
outOfDirectives_na = get_na(lots, column='outOfDirectives')

# %%
outOfDirectives_na
# Out:
#   attribut    count  proportion
# 0   manque        0         0.0
# 1    exist  1380965       100.0

# %% [markdown]
# # Attribut contractorSme

# %%
contractorSme = lots[['contractorSme']]

# %%
contractorSme
# Out:
#         contractorSme
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1380960             Y
# 1380961             N
# 1380962             N
# 1380963         N---N
# 1380964             N
#
# [1380965 rows x 1 columns]

# %%
contractorSme_vc = get_vc(lots, column='contractorSme')

# %%
contractorSme_vc
# Out:
#                                                 valeur   count  proportion
# 0                                                    N  228827   51.360396
# 1                                                    Y  179297   40.243350
# 2                                                N---N   10263    2.303538
# 3                                                Y---Y    8507    1.909403
# 4                                            Y---Y---Y    3528    0.791862
# ..                                                 ...     ...         ...
# 447                          N---Y---N---N---Y---N---N       1    0.000224
# 448                      N---Y---Y---N---N---N---N---N       1    0.000224
# 449              Y---Y---N---Y---Y---Y---Y---Y---N---N       1    0.000224
# 450  Y---N---Y---N---Y---Y---Y---N---N---Y---Y---Y---Y       1    0.000224
# 451  N---N---N---N---N---N---N---N---N---N---N---N-...       1    0.000224
#
# [452 rows x 3 columns]

# %%
contractorSme_na = get_na(lots, column='contractorSme')

# %%
contractorSme_na
# Out:
#   attribut   count  proportion
# 0   manque  935433   67.737633
# 1    exist  445532   32.262367

# %%
plot_proportion(
    data=contractorSme_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de contractorSme', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_contractorSme_01.png',
    logy=True
)

# %%
contractorSme_cat = categorized_contractorSme(contractorSme)

# %%
contractorSme_cat
# Out:
#         contractorSme    category
# 0                 NaN     missing
# 1                 NaN     missing
# 2                 NaN     missing
# 3                 NaN     missing
# 4                 NaN     missing
# ...               ...         ...
# 1380960             Y     correct
# 1380961             N     correct
# 1380962             N     correct
# 1380963         N---N  repetition
# 1380964             N     correct
#
# [1380965 rows x 2 columns]

# %%
contractorSme_cat_vc = get_vc(contractorSme_cat, column='category')

# %%
contractorSme_cat_vc
# Out:
#        valeur   count  proportion
# 0     missing  935433   67.737633
# 1     correct  408124   29.553537
# 2  repetition   37408    2.708830

# %%
plot_proportion(
    data=contractorSme_cat_vc,
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs contractorSme', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_contractorSme_02.png',
    logy=True
)

# %% [markdown]
# # Attribut numberTendersSme

# %%
numberTendersSme = lots[['numberTendersSme']]

# %%
numberTendersSme
# Out:
#          numberTendersSme
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1380960               NaN
# 1380961               NaN
# 1380962               NaN
# 1380963               NaN
# 1380964               NaN
#
# [1380965 rows x 1 columns]

# %%
numberTendersSme_vc = get_vc(lots, column='numberTendersSme')

# %%
numberTendersSme_vc
# Out:
#     valeur  count  proportion
# 0      1.0  11250   25.553082
# 1      0.0   8015   18.205152
# 2      2.0   7943   18.041612
# 3      3.0   5921   13.448871
# 4      4.0   3524    8.004361
# 5      5.0   2212    5.024304
# 6      6.0   1378    3.129969
# 7      7.0    825    1.873893
# 8      8.0    611    1.387816
# 9      9.0    473    1.074365
# 10    10.0    256    0.581475
# 11    11.0    212    0.481534
# 12    15.0    205    0.465634
# 13    12.0    145    0.329351
# 14    14.0    120    0.272566
# 15    13.0    115    0.261209
# 16    16.0     96    0.218053
# 17    70.0     69    0.156726
# 18    22.0     69    0.156726
# 19    68.0     61    0.138554
# 20    52.0     61    0.138554
# 21    77.0     48    0.109026
# 22    17.0     44    0.099941
# 23    21.0     39    0.088584
# 24    27.0     38    0.086313
# 25    43.0     33    0.074956
# 26    32.0     32    0.072684
# 27    19.0     28    0.063599
# 28    40.0     27    0.061327
# 29    18.0     26    0.059056
# 30    25.0     21    0.047699
# 31    28.0     19    0.043156
# 32    59.0     19    0.043156
# 33    23.0     15    0.034071
# 34    20.0     14    0.031799
# 35    36.0     11    0.024985
# 36    38.0      9    0.020442
# 37    24.0      7    0.015900
# 38    26.0      7    0.015900
# 39    30.0      4    0.009086
# 40    34.0      4    0.009086
# 41    31.0      3    0.006814
# 42    35.0      2    0.004543
# 43    42.0      2    0.004543
# 44    29.0      2    0.004543
# 45    76.0      1    0.002271
# 46    39.0      1    0.002271
# 47    63.0      1    0.002271
# 48    65.0      1    0.002271
# 49    41.0      1    0.002271
# 50    58.0      1    0.002271
# 51    53.0      1    0.002271
# 52    50.0      1    0.002271
# 53    54.0      1    0.002271
# 54    47.0      1    0.002271
# 55    60.0      1    0.002271

# %%
numberTendersSme_na = get_na(lots, column='numberTendersSme')

# %%
numberTendersSme_na
# Out:
#   attribut    count  proportion
# 0   manque  1336939   96.811939
# 1    exist    44026    3.188061

# %%
plot_proportion(
    data=numberTendersSme_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de numberTendersSme', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_numberTendersSme_01.png',
    logy=True
)

# %% [markdown]
# # Attribut subContracted

# %%
subContracted = lots[['subContracted']]

# %%
subContracted
# Out:
#         subContracted
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                   N
# ...               ...
# 1380960           NaN
# 1380961           NaN
# 1380962           NaN
# 1380963           NaN
# 1380964           NaN
#
# [1380965 rows x 1 columns]

# %%
subContracted_vc = get_vc(lots, column='subContracted')

# %%
subContracted_vc
# Out:
#   valeur   count  proportion
# 0      N  597692   85.418739
# 1      Y  102028   14.581261

# %%
subContracted_na = get_na(lots, column='subContracted')

# %%
subContracted_na
# Out:
#   attribut   count  proportion
# 0   manque  681245   49.331084
# 1    exist  699720   50.668916

# %%
plot_proportion(
    data=subContracted_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de subContracted', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_subContracted_01.png',
    logy=False
)

# %% [markdown]
# # Attribut gpa

# %%
gpa = lots['gpa']

# %%
gpa
# Out:
# 0            Y
# 1            Y
# 2            Y
# 3            N
# 4            N
#           ...
# 1380960    NaN
# 1380961    NaN
# 1380962    NaN
# 1380963    NaN
# 1380964    NaN
# Name: gpa, Length: 1380965, dtype: object

# %%
gpa_vc = get_vc(lots, column='gpa')

# %%
gpa_vc
# Out:
#   valeur   count  proportion
# 0      Y  918191   84.577101
# 1      N  167435   15.422899

# %%
gpa_na = get_na(lots, column='gpa')

# %%
gpa_na
# Out:
#   attribut    count  proportion
# 0   manque   295339   21.386422
# 1    exist  1085626   78.613578

# %%
plot_proportion(
    data=gpa_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de gpa', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_gpa_01.png',
    logy=False
)

# %% [markdown]
# # Attribut multipleCae

# %%
multipleCae = lots[['multipleCae']]

# %%
multipleCae
# Out:
#         multipleCae
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1380960           N
# 1380961           N
# 1380962           N
# 1380963           N
# 1380964           N
#
# [1380965 rows x 1 columns]

# %%
multipleCae_vc = get_vc(lots, column='multipleCae')

# %%
multipleCae_vc
# Out:
#   valeur   count  proportion
# 0      N  506992    93.67075
# 1      Y   34257     6.32925

# %%
multipleCae_na = get_na(lots, column='multipleCae')

# %%
multipleCae_na
# Out:
#   attribut   count  proportion
# 0   manque  839716   60.806465
# 1    exist  541249   39.193535

# %%
plot_proportion(
    data=multipleCae_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de multipleCae', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_multipleCae_01.png',
    logy=False
)

# %% [markdown]
# # Attribut typeOfContract

# %%
typeOfContract = lots[['typeOfContract']]

# %%
typeOfContract
# Out:
#         typeOfContract
# 0                    W
# 1                    W
# 2                    W
# 3                    W
# 4                    W
# ...                ...
# 1380960              S
# 1380961              S
# 1380962              S
# 1380963              S
# 1380964              S
#
# [1380965 rows x 1 columns]

# %%
typeOfContract_vc = get_vc(lots, column='typeOfContract')

# %%
typeOfContract_vc
# Out:
#   valeur   count  proportion
# 0      U  554638   40.163074
# 1      S  550055   39.831205
# 2      W  276272   20.005721

# %%
typeOfContract_na = get_na(lots, column='typeOfContract')

# %%
typeOfContract_na
# Out:
#   attribut    count  proportion
# 0   manque        0         0.0
# 1    exist  1380965       100.0

# %% [markdown]
# # Attribut topType

# %%
topType = lots[['topType']]

# %%
topType
# Out:
#         topType
# 0           OPE
# 1           OPE
# 2           OPE
# 3           OPE
# 4           RES
# ...         ...
# 1380960     NIC
# 1380961     NIC
# 1380962     NIC
# 1380963     NOC
# 1380964     NOC
#
# [1380965 rows x 1 columns]

# %%
topType_vc = get_vc(lots, column='topType')

# %%
topType_vc
# Out:
#   valeur    count  proportion
# 0    OPE  1165396   84.401647
# 1    NIC   103848    7.520999
# 2    AWP    65077    4.713081
# 3    RES    24152    1.749164
# 4    NOC    17736    1.284497
# 5    COD     2799    0.202712
# 6    NIP     1227    0.088863
# 7    NOP      506    0.036646
# 8    INP       33    0.002390

# %%
topType_na = get_na(lots, column='topType')

# %%
topType_na
# Out:
#   attribut    count  proportion
# 0   manque      191    0.013831
# 1    exist  1380774   99.986169

# %%
plot_proportion(
    data=topType_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de topType', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_topType_01.png',
    logy=True
)

# %% [markdown]
# # Attribut renewal

# %%
renewal = lots[['renewal']]

# %%
renewal
# Out:
#         renewal
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1380960     NaN
# 1380961     NaN
# 1380962     NaN
# 1380963     NaN
# 1380964     NaN
#
# [1380965 rows x 1 columns]

# %%
renewal_vc = get_vc(lots, column='renewal')

# %%
renewal_vc
# Out:
#   valeur   count  proportion
# 0      Y  485204    67.65933
# 1      N  231924    32.34067

# %%
renewal_na = get_na(lots, column='renewal')

# %%
renewal_na
# Out:
#   attribut   count  proportion
# 0   manque  663837   48.070516
# 1    exist  717128   51.929484

# %%
plot_proportion(
    data=renewal_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de renewal', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_renewal_01.png',
    logy=False
)

# %% [markdown]
# # Attribut contractDuration

# %%
contractDuration = lots[['contractDuration']]

# %%
contractDuration
# Out:
#          contractDuration
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                   24.01
# ...                   ...
# 1380960             96.00
# 1380961               NaN
# 1380962             60.00
# 1380963               NaN
# 1380964               NaN
#
# [1380965 rows x 1 columns]

# %%
contractDuration_vc = get_vc(lots, column='contractDuration')

# %%
contractDuration_vc
# Out:
#       valeur   count  proportion
# 0      12.00  215824   25.608946
# 1      48.00  145029   17.208651
# 2      36.00   57506    6.823467
# 3      11.97   54220    6.433562
# 4      24.00   48646    5.772170
# ...      ...     ...         ...
# 1981  240.30       1    0.000119
# 1982   53.42       1    0.000119
# 1983   35.39       1    0.000119
# 1984   59.47       1    0.000119
# 1985   95.63       1    0.000119
#
# [1986 rows x 3 columns]

# %%
contractDuration_na = get_na(lots, column='contractDuration')

# %%
contractDuration_na
# Out:
#   attribut   count  proportion
# 0   manque  538197    38.97253
# 1    exist  842768    61.02747

# %%
plot_proportion(
    data=contractDuration_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de contractDuration', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_contractDuration_01.png',
    logy=False
)

# %% [markdown]
# # Attribut publicityDuration

# %%
publicityDuration = lots[['publicityDuration']]

# %%
publicityDuration
# Out:
#          publicityDuration
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                     36.0
# ...                    ...
# 1380960               35.0
# 1380961               62.0
# 1380962               35.0
# 1380963                NaN
# 1380964                NaN
#
# [1380965 rows x 1 columns]

# %%
publicityDuration_vc = get_vc(lots, column='publicityDuration')

# %%
publicityDuration_vc
# Out:
#      valeur  count  proportion
# 0      42.0  99742    9.633427
# 1      41.0  90643    8.754614
# 2      31.0  44656    4.313031
# 3      43.0  44517    4.299606
# 4      32.0  41235    3.982619
# ..      ...    ...         ...
# 225   228.0      1    0.000097
# 226   151.0      1    0.000097
# 227   159.0      1    0.000097
# 228   197.0      1    0.000097
# 229   162.0      1    0.000097
#
# [230 rows x 3 columns]

# %%
publicityDuration_na = get_na(lots, column='publicityDuration')

# %%
publicityDuration_na
# Out:
#   attribut    count  proportion
# 0   manque   345591   25.025326
# 1    exist  1035374   74.974674

# %%
plot_proportion(
    data=publicityDuration_na,
    xcol='attribut', 
    ycol='proportion', 
    title='Proportion des catégories de valeurs de publicityDuration', 
    xtitle='catégorie de valeur', 
    ytitle='proportion',
    saveas='../images/01_problemes_publicityDuration_01.png',
    logy=False
)
