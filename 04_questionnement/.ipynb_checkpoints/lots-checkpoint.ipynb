# %%
from functions.utils import *
import warnings

warnings.filterwarnings('ignore')

# %%
lots = load_data(path='../donnees/lots_cleaned.csv')

# %%
lots
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 0              0     2010142              0          0  2009-09-24
# 1              1     2010142              0          0  2009-09-24
# 2              2     2010142              0          0  2009-09-24
# 3              3     2010143              0          0  2009-09-28
# 4              4     2010144              0          0  2009-11-06
# ...          ...         ...            ...        ...         ...
# 1380960  1380960  2020643360              0          0  2020-12-28
# 1380961  1380961  2020643361              0          0  2020-12-10
# 1380962  1380962  2020643362              0          0  2020-12-17
# 1380963  1380963  2020643363              0          0  2020-12-11
# 1380964  1380964  2020643364              0          0  2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                   100000.0  8.916747e+05  45233226.0            2.0
# 1                   100000.0  1.169251e+05  45233226.0            2.0
# 2                   100000.0  7.381412e+04  45233226.0            2.0
# 3                   100000.0  3.840584e+05  45232150.0           11.0
# 4                   100000.0  7.790000e+06  45211000.0            6.0
# ...                      ...           ...         ...            ...
# 1380960             100000.0  5.000000e+05  92200000.0            2.0
# 1380961             100000.0  2.000000e+07  65111000.0            2.0
# 1380962             100000.0  4.984029e+06  85312110.0            3.0
# 1380963          497000000.0  4.970000e+08  65300000.0            1.0
# 1380964                  1.0  1.000000e+00  65310000.0            1.0
#
#         onBehalf  ... contractorSme numberTendersSme subContracted  gpa  \
# 0              N  ...             N              1.0             N    Y
# 1              N  ...             N              1.0             N    Y
# 2              N  ...             N              1.0             N    Y
# 3              N  ...             N              1.0             N    N
# 4              N  ...             N              1.0             N    N
# ...          ...  ...           ...              ...           ...  ...
# 1380960        N  ...             Y              1.0             N    Y
# 1380961        N  ...             N              1.0             N    Y
# 1380962        N  ...             N              1.0             N    Y
# 1380963        N  ...             N              1.0             N    Y
# 1380964        N  ...             N              1.0             N    Y
#
#         multipleCae  typeOfContract topType  renewal contractDuration  \
# 0                 N               W     OPE        Y            24.00
# 1                 N               W     OPE        Y            24.00
# 2                 N               W     OPE        Y            24.00
# 3                 N               W     OPE        Y            24.00
# 4                 N               W     RES        Y            24.01
# ...             ...             ...     ...      ...              ...
# 1380960           N               S     NIC        Y            96.00
# 1380961           N               S     NIC        Y            24.00
# 1380962           N               S     NIC        Y            60.00
# 1380963           N               S     NOC        Y            24.00
# 1380964           N               S     NOC        Y            24.00
#
#         publicityDuration
# 0                    42.0
# 1                    42.0
# 2                    42.0
# 3                    42.0
# 4                    36.0
# ...                   ...
# 1380960              35.0
# 1380961              62.0
# 1380962              35.0
# 1380963              42.0
# 1380964              42.0
#
# [1380965 rows x 26 columns]

# %%
lots.dtypes
# Out:
# lotId                    int64
# tedCanId                 int64
# correctionsNb            int64
# cancelled                int64
# awardDate               object
# awardEstimatedPrice    float64
# awardPrice             float64
# cpv                    float64
# numberTenders          float64
# onBehalf                object
# jointProcurement        object
# fraAgreement            object
# fraEstimated            object
# lotsNumber               int64
# accelerated             object
# outOfDirectives          int64
# contractorSme           object
# numberTendersSme       float64
# subContracted           object
# gpa                     object
# multipleCae             object
# typeOfContract          object
# topType                 object
# renewal                 object
# contractDuration       float64
# publicityDuration      float64
# dtype: object

# %% [markdown]
# # Question 1
#
# Q1: peut-on identifier des classes de similarité d’agents économiques? Des lots?

# %%
numeric_columns = [
    'correctionsNb', 'awardEstimatedPrice', 'awardPrice', 'numberTenders', 
    'lotsNumber', 'numberTendersSme','contractDuration','publicityDuration'
]

# %%
categorical_columns = [
    'cancelled', 'year', 'cpv', 'onBehalf', 'jointProcurement', 
    'fraAgreement', 'fraEstimated', 'accelerated', 'outOfDirectives',
    'subContracted', 'gpa', 'multipleCae', 'typeOfContract', 'topType', 'renewal'
]

# %% [raw]
# lots = get_awardDate_info(lots)

# %% [raw]
# best_k = run_multiple_kmeans(
#     data=lots,
#     numeric_columns = numeric_columns,
#     categorical_columns = categorical_columns,
#     end = 20,
#     saveas = '../images/04_questions_lots_01.png'
# )

# %% [raw]
# best_k

# %% [raw]
# clusters_1, inertia_1 = do_kmeans(
#     data=lots,
#     numeric_columns = numeric_columns,
#     categorical_columns = categorical_columns,
#     k=best_k
# )

# %% [raw]
# save_data(
#     df = clusters_1,
#     path = '../donnees/lots_cleaned_clusters.csv'
# )

# %%
clusters_1 = load_data(path='../donnees/lots_cleaned_clusters.csv')

# %%
clusters_1
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 0              0     2010142              0          0  2009-09-24
# 1              1     2010142              0          0  2009-09-24
# 2              2     2010142              0          0  2009-09-24
# 3              3     2010143              0          0  2009-09-28
# 4              4     2010144              0          0  2009-11-06
# ...          ...         ...            ...        ...         ...
# 1380960  1380960  2020643360              0          0  2020-12-28
# 1380961  1380961  2020643361              0          0  2020-12-10
# 1380962  1380962  2020643362              0          0  2020-12-17
# 1380963  1380963  2020643363              0          0  2020-12-11
# 1380964  1380964  2020643364              0          0  2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                   100000.0  8.916747e+05  45233226.0            2.0
# 1                   100000.0  1.169251e+05  45233226.0            2.0
# 2                   100000.0  7.381412e+04  45233226.0            2.0
# 3                   100000.0  3.840584e+05  45232150.0           11.0
# 4                   100000.0  7.790000e+06  45211000.0            6.0
# ...                      ...           ...         ...            ...
# 1380960             100000.0  5.000000e+05  92200000.0            2.0
# 1380961             100000.0  2.000000e+07  65111000.0            2.0
# 1380962             100000.0  4.984029e+06  85312110.0            3.0
# 1380963          497000000.0  4.970000e+08  65300000.0            1.0
# 1380964                  1.0  1.000000e+00  65310000.0            1.0
#
#         onBehalf  ... gpa multipleCae typeOfContract  topType renewal  \
# 0              N  ...   Y           N              W      OPE       Y
# 1              N  ...   Y           N              W      OPE       Y
# 2              N  ...   Y           N              W      OPE       Y
# 3              N  ...   N           N              W      OPE       Y
# 4              N  ...   N           N              W      RES       Y
# ...          ...  ...  ..         ...            ...      ...     ...
# 1380960        N  ...   Y           N              S      NIC       Y
# 1380961        N  ...   Y           N              S      NIC       Y
# 1380962        N  ...   Y           N              S      NIC       Y
# 1380963        N  ...   Y           N              S      NOC       Y
# 1380964        N  ...   Y           N              S      NOC       Y
#
#          contractDuration publicityDuration  year month cluster
# 0                   24.00              42.0  2009     9       0
# 1                   24.00              42.0  2009     9       0
# 2                   24.00              42.0  2009     9       0
# 3                   24.00              42.0  2009     9       0
# 4                   24.01              36.0  2009    11       8
# ...                   ...               ...   ...   ...     ...
# 1380960             96.00              35.0  2020    12       6
# 1380961             24.00              62.0  2020    12       0
# 1380962             60.00              35.0  2020    12       6
# 1380963             24.00              42.0  2020    12       0
# 1380964             24.00              42.0  2020    12       0
#
# [1380965 rows x 29 columns]

# %% [markdown]
# # Question 2
#
# Q2: quelles sont les variables et valeurs qui permettent de distinguer ces classes et/ou qui sont caractéristiques de certaines classes?

# %%
cluster_1_corr_cat, cluster_1_corr_num = get_all_corr_cat(
    data = clusters_1, 
    col = 'cluster', 
    num_cols = numeric_columns, 
    cat_cols = categorical_columns
)

# %%
cluster_1_corr_cat.sort_values(by='cluster', ascending=False)
# Out:
#                    cluster
# fraAgreement      0.880786
# renewal           0.303844
# cpv               0.217361
# typeOfContract    0.193174
# outOfDirectives   0.145838
# onBehalf          0.099392
# jointProcurement  0.086178
# multipleCae       0.085720
# gpa               0.080407
# fraEstimated      0.073149
# year              0.069806
# topType           0.063170
# subContracted     0.022560
# accelerated       0.015315
# cancelled         0.012386

# %%
cluster_1_corr_num
# Out:
#                      cluster
# correctionsNb            0.0
# awardEstimatedPrice      0.0
# awardPrice               0.0
# numberTenders            0.0
# lotsNumber               0.0
# numberTendersSme         0.0
# contractDuration         0.0
# publicityDuration        0.0

# %% [markdown]
# # Question 3
#
# Q3: comment interpréter ces classes, que signifient-elles?

# %% [markdown]
# # Question 4
#
# Q4: y a-t-il des anomalies (lots ou agents)?

# %% [markdown]
# # Question 5
#
# Q5: si oui, lesquelles et comment les expliquer?

# %% [markdown]
# # Question 6
#
# Q6: y a-t-il des différences entre agents et lots issus de secteurs d’activité différents?

# %% [markdown]
# # Question 7
#
# Q7: Si oui, lesquelles, et comment les interpréter?

# %% [markdown]
# # Question 8
#
# Q8: y a-t-il des différences entre agents et lots issus de divisions administratives différentes?

# %% [markdown]
# # Question 9
#
# Q9: Si oui, lesquelles, et comment les interpréter?

# %% [markdown]
# # Question 10
#
# Q10:Y a-t-il un lien entre l’attribution d’un contrat et la distance spatiale séparant l’acheteur et le fournisseur remportant le marché?

# %% [markdown]
# # Question 11
#
# Q11: Ou bien entre cette distance et le montant du contrat, voire une autre variable?

# %% [markdown]
# # Question 12
#
# Q12: quelle est la part des PME dans la commande publique? Par secteur? Par type d’acheteur?
