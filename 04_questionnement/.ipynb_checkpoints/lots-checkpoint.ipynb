# %%
from functions.utils import *
import warnings

warnings.filterwarnings('ignore')

# %%
lots = load_data(path='../donnees/lots_cleaned.csv')

# %%
lots
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 0              0     2010142              0          0  2009-09-24
# 1              1     2010142              0          0  2009-09-24
# 2              2     2010142              0          0  2009-09-24
# 3              3     2010143              0          0  2009-09-28
# 4              4     2010144              0          0  2009-11-06
# ...          ...         ...            ...        ...         ...
# 1380960  1380960  2020643360              0          0  2020-12-28
# 1380961  1380961  2020643361              0          0  2020-12-10
# 1380962  1380962  2020643362              0          0  2020-12-17
# 1380963  1380963  2020643363              0          0  2020-12-11
# 1380964  1380964  2020643364              0          0  2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                   100000.0  8.916747e+05  45233226.0            2.0
# 1                   100000.0  1.169251e+05  45233226.0            2.0
# 2                   100000.0  7.381412e+04  45233226.0            2.0
# 3                   100000.0  3.840584e+05  45232150.0           11.0
# 4                   100000.0  7.790000e+06  45211000.0            6.0
# ...                      ...           ...         ...            ...
# 1380960             100000.0  5.000000e+05  92200000.0            2.0
# 1380961             100000.0  2.000000e+07  65111000.0            2.0
# 1380962             100000.0  4.984029e+06  85312110.0            3.0
# 1380963          497000000.0  4.970000e+08  65300000.0            1.0
# 1380964                  1.0  1.000000e+00  65310000.0            1.0
#
#         onBehalf  ... contractorSme numberTendersSme subContracted  gpa  \
# 0              N  ...             N              1.0             N    Y
# 1              N  ...             N              1.0             N    Y
# 2              N  ...             N              1.0             N    Y
# 3              N  ...             N              1.0             N    N
# 4              N  ...             N              1.0             N    N
# ...          ...  ...           ...              ...           ...  ...
# 1380960        N  ...             Y              1.0             N    Y
# 1380961        N  ...             N              1.0             N    Y
# 1380962        N  ...             N              1.0             N    Y
# 1380963        N  ...             N              1.0             N    Y
# 1380964        N  ...             N              1.0             N    Y
#
#         multipleCae  typeOfContract topType  renewal contractDuration  \
# 0                 N               W     OPE        Y            24.00
# 1                 N               W     OPE        Y            24.00
# 2                 N               W     OPE        Y            24.00
# 3                 N               W     OPE        Y            24.00
# 4                 N               W     RES        Y            24.01
# ...             ...             ...     ...      ...              ...
# 1380960           N               S     NIC        Y            96.00
# 1380961           N               S     NIC        Y            24.00
# 1380962           N               S     NIC        Y            60.00
# 1380963           N               S     NOC        Y            24.00
# 1380964           N               S     NOC        Y            24.00
#
#         publicityDuration
# 0                    42.0
# 1                    42.0
# 2                    42.0
# 3                    42.0
# 4                    36.0
# ...                   ...
# 1380960              35.0
# 1380961              62.0
# 1380962              35.0
# 1380963              42.0
# 1380964              42.0
#
# [1380965 rows x 26 columns]

# %%
lots.dtypes
# Out:
# lotId                    int64
# tedCanId                 int64
# correctionsNb            int64
# cancelled                int64
# awardDate               object
# awardEstimatedPrice    float64
# awardPrice             float64
# cpv                    float64
# numberTenders          float64
# onBehalf                object
# jointProcurement        object
# fraAgreement            object
# fraEstimated            object
# lotsNumber               int64
# accelerated             object
# outOfDirectives          int64
# contractorSme           object
# numberTendersSme       float64
# subContracted           object
# gpa                     object
# multipleCae             object
# typeOfContract          object
# topType                 object
# renewal                 object
# contractDuration       float64
# publicityDuration      float64
# dtype: object

# %% [markdown]
# # Question 1
#
# Q1: peut-on identifier des classes de similarité d’agents économiques? Des lots?

# %%
numeric_columns = [
    'correctionsNb', 'awardEstimatedPrice', 'awardPrice', 'numberTenders', 
    'lotsNumber', 'numberTendersSme','contractDuration','publicityDuration'
]

# %%
categorical_columns = [
    'cancelled', 'year', 'cpv', 'onBehalf', 'jointProcurement', 
    'fraAgreement', 'fraEstimated', 'accelerated', 'outOfDirectives',
    'subContracted', 'gpa', 'multipleCae', 'typeOfContract', 'topType', 'renewal'
]

# %%
lots = get_awardDate_info(lots)

# %% [raw]
# best_k = run_multiple_kmeans(
#     data=lots,
#     numeric_columns = numeric_columns,
#     categorical_columns = categorical_columns,
#     end = 20,
#     saveas = '../images/04_questions_lots_01.png'
# )

# %% [raw]
# best_k

# %% [raw]
# clusters_1, inertia_1 = do_kmeans(
#     data=lots,
#     numeric_columns = numeric_columns,
#     categorical_columns = categorical_columns,
#     k=best_k
# )

# %% [raw]
# save_data(
#     df = clusters_1,
#     path = '../donnees/lots_cleaned_clusters.csv'
# )

# %%
clusters_1 = load_data(path='../donnees/lots_cleaned_clusters.csv')

# %%
clusters_1
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 0              0     2010142              0          0  2009-09-24
# 1              1     2010142              0          0  2009-09-24
# 2              2     2010142              0          0  2009-09-24
# 3              3     2010143              0          0  2009-09-28
# 4              4     2010144              0          0  2009-11-06
# ...          ...         ...            ...        ...         ...
# 1380960  1380960  2020643360              0          0  2020-12-28
# 1380961  1380961  2020643361              0          0  2020-12-10
# 1380962  1380962  2020643362              0          0  2020-12-17
# 1380963  1380963  2020643363              0          0  2020-12-11
# 1380964  1380964  2020643364              0          0  2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                   100000.0  8.916747e+05  45233226.0            2.0
# 1                   100000.0  1.169251e+05  45233226.0            2.0
# 2                   100000.0  7.381412e+04  45233226.0            2.0
# 3                   100000.0  3.840584e+05  45232150.0           11.0
# 4                   100000.0  7.790000e+06  45211000.0            6.0
# ...                      ...           ...         ...            ...
# 1380960             100000.0  5.000000e+05  92200000.0            2.0
# 1380961             100000.0  2.000000e+07  65111000.0            2.0
# 1380962             100000.0  4.984029e+06  85312110.0            3.0
# 1380963          497000000.0  4.970000e+08  65300000.0            1.0
# 1380964                  1.0  1.000000e+00  65310000.0            1.0
#
#         onBehalf  ... gpa multipleCae typeOfContract  topType renewal  \
# 0              N  ...   Y           N              W      OPE       Y
# 1              N  ...   Y           N              W      OPE       Y
# 2              N  ...   Y           N              W      OPE       Y
# 3              N  ...   N           N              W      OPE       Y
# 4              N  ...   N           N              W      RES       Y
# ...          ...  ...  ..         ...            ...      ...     ...
# 1380960        N  ...   Y           N              S      NIC       Y
# 1380961        N  ...   Y           N              S      NIC       Y
# 1380962        N  ...   Y           N              S      NIC       Y
# 1380963        N  ...   Y           N              S      NOC       Y
# 1380964        N  ...   Y           N              S      NOC       Y
#
#          contractDuration publicityDuration  year month cluster
# 0                   24.00              42.0  2009     9       0
# 1                   24.00              42.0  2009     9       0
# 2                   24.00              42.0  2009     9       0
# 3                   24.00              42.0  2009     9       0
# 4                   24.01              36.0  2009    11       8
# ...                   ...               ...   ...   ...     ...
# 1380960             96.00              35.0  2020    12       6
# 1380961             24.00              62.0  2020    12       0
# 1380962             60.00              35.0  2020    12       6
# 1380963             24.00              42.0  2020    12       0
# 1380964             24.00              42.0  2020    12       0
#
# [1380965 rows x 29 columns]

# %% [markdown]
# # Question 2
#
# Q2: quelles sont les variables et valeurs qui permettent de distinguer ces classes et/ou qui sont caractéristiques de certaines classes?

# %%
cluster_1_corr_cat, cluster_1_corr_num = get_all_corr_cat(
    data = clusters_1, 
    col = 'cluster', 
    num_cols = numeric_columns, 
    cat_cols = categorical_columns
)

# %%
cluster_1_corr_cat.sort_values(by='cluster', ascending=False)
# Out:
#                    cluster
# fraAgreement      0.880786
# renewal           0.303844
# cpv               0.217361
# typeOfContract    0.193174
# outOfDirectives   0.145838
# onBehalf          0.099392
# jointProcurement  0.086178
# multipleCae       0.085720
# gpa               0.080407
# fraEstimated      0.073149
# year              0.069806
# topType           0.063170
# subContracted     0.022560
# accelerated       0.015315
# cancelled         0.012386

# %%
cluster_1_corr_num
# Out:
#                      cluster
# correctionsNb            0.0
# awardEstimatedPrice      0.0
# awardPrice               0.0
# numberTenders            0.0
# lotsNumber               0.0
# numberTendersSme         0.0
# contractDuration         0.0
# publicityDuration        0.0

# %% [markdown]
# # Question 3
#
# Q3: comment interpréter ces classes, que signifient-elles?

# %%
fraAgreement_corr_data = get_corr_cat_2_cat_data(
    df = clusters_1, 
    xcol = 'cluster', 
    ycol = 'fraAgreement'
)

# %%
fraAgreement_corr_data
# Out:
# fraAgreement       N       Y
# cluster
# 0             741354       0
# 1              10886    7490
# 2                  3       0
# 3                367      31
# 4                 48       5
# 5               4034    1145
# 6             142808  119140
# 7                  2       0
# 8                  0  353650
# 9                  1       1

# %%
plot_categorial_categorical(
    data=fraAgreement_corr_data,
    title="Correlation entre le cluster de lot et fraAgreement",
    xlabel="cluster",
    ylabel="fraAgreement",
    saveas='../images/04_quest_lots_02.png',
    logy=True
)

# %% [markdown]
# # Question 4
#
# Q4: y a-t-il des anomalies (lots ou agents)?

# %%
clusters_1_anomalies = detect_anomalies(
    data =clusters_1, 
    numeric_columns = numeric_columns, 
    categorical_columns = categorical_columns
)

# %%
clusters_1_anomalies
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 0              0     2010142              0          0  2009-09-24
# 1              1     2010142              0          0  2009-09-24
# 2              2     2010142              0          0  2009-09-24
# 3              3     2010143              0          0  2009-09-28
# 4              4     2010144              0          0  2009-11-06
# ...          ...         ...            ...        ...         ...
# 1380960  1380960  2020643360              0          0  2020-12-28
# 1380961  1380961  2020643361              0          0  2020-12-10
# 1380962  1380962  2020643362              0          0  2020-12-17
# 1380963  1380963  2020643363              0          0  2020-12-11
# 1380964  1380964  2020643364              0          0  2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                   100000.0  8.916747e+05  45233226.0            2.0
# 1                   100000.0  1.169251e+05  45233226.0            2.0
# 2                   100000.0  7.381412e+04  45233226.0            2.0
# 3                   100000.0  3.840584e+05  45232150.0           11.0
# 4                   100000.0  7.790000e+06  45211000.0            6.0
# ...                      ...           ...         ...            ...
# 1380960             100000.0  5.000000e+05  92200000.0            2.0
# 1380961             100000.0  2.000000e+07  65111000.0            2.0
# 1380962             100000.0  4.984029e+06  85312110.0            3.0
# 1380963          497000000.0  4.970000e+08  65300000.0            1.0
# 1380964                  1.0  1.000000e+00  65310000.0            1.0
#
#         onBehalf  ... multipleCae typeOfContract topType  renewal  \
# 0              N  ...           N              W     OPE        Y
# 1              N  ...           N              W     OPE        Y
# 2              N  ...           N              W     OPE        Y
# 3              N  ...           N              W     OPE        Y
# 4              N  ...           N              W     RES        Y
# ...          ...  ...         ...            ...     ...      ...
# 1380960        N  ...           N              S     NIC        Y
# 1380961        N  ...           N              S     NIC        Y
# 1380962        N  ...           N              S     NIC        Y
# 1380963        N  ...           N              S     NOC        Y
# 1380964        N  ...           N              S     NOC        Y
#
#         contractDuration  publicityDuration  year  month cluster anomaly
# 0                  24.00               42.0  2009      9       0   False
# 1                  24.00               42.0  2009      9       0   False
# 2                  24.00               42.0  2009      9       0   False
# 3                  24.00               42.0  2009      9       0   False
# 4                  24.01               36.0  2009     11       8   False
# ...                  ...                ...   ...    ...     ...     ...
# 1380960            96.00               35.0  2020     12       6   False
# 1380961            24.00               62.0  2020     12       0   False
# 1380962            60.00               35.0  2020     12       6   False
# 1380963            24.00               42.0  2020     12       0   False
# 1380964            24.00               42.0  2020     12       0   False
#
# [1380965 rows x 30 columns]

# %%
clusters_1_anomalies_corr_data = get_corr_cat_2_cat_data(
    df = clusters_1_anomalies, 
    xcol = 'cluster', 
    ycol = 'anomaly'
)

# %%
clusters_1_anomalies_corr_data
# Out:
# anomaly   False  True
# cluster
# 0        741354      0
# 1         18349     27
# 2             3      0
# 3           349     49
# 4            41     12
# 5          5179      0
# 6        261948      0
# 7             2      0
# 8        353650      0
# 9             2      0

# %%
plot_categorial_categorical(
    data=clusters_1_anomalies_corr_data,
    title="Annomalies par cluster",
    xlabel="cluster",
    ylabel="annomaly",
    saveas='../images/04_quest_lots_03.png',
    logy=True
)

# %%
get_anomaly_cluster(
    data = clusters_1_anomalies, 
    clusterId = 1
)
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 951981    951981  2017257320              0          0  2017-05-22
# 1237932  1237932  2019452719              0          0  2019-09-18
# 1362875  1362875  2020554137              0          0  2020-10-13
# 1362876  1362876  2020554137              0          0  2020-10-12
# 1362877  1362877  2020554137              0          0  2020-10-12
# 1362878  1362878  2020554137              0          0  2020-10-12
# 1362879  1362879  2020554137              0          0  2020-10-06
# 1362881  1362881  2020554137              0          0  2020-10-02
# 1362882  1362882  2020554137              0          0  2020-10-02
# 1362883  1362883  2020554137              0          0  2020-10-02
# 1362884  1362884  2020554137              0          0  2020-10-07
# 1362885  1362885  2020554137              0          0  2020-10-01
# 1071962             100000.0   314328.00  71000000.0           53.0        N
# 1098467            5000000.0        1.00  60130000.0           34.0        N
# 1118943              18825.0    18825.00  15800000.0            3.0        Y
# 1123051             279000.0   279000.00  71200000.0           41.0        N
# 1160945             100000.0  1038639.00  79100000.0          102.0        N
# 1160946             100000.0   891273.00  79100000.0          102.0        N
# 1160947             100000.0  6697031.00  79100000.0          102.0        N
# 1160950             100000.0  3285400.00  79100000.0          102.0        N
# 1189216             100000.0   314467.50  71200000.0           42.0        N
# 1198099             100000.0   564340.50  71000000.0           30.0        N
# 1229280            3087400.0   302423.99  71000000.0           34.0        N
# 1355969             100000.0   640000.00  33140000.0           45.0        N
# 1356689             100000.0    28400.00  18143000.0           43.0        N
# 1356690             100000.0    24400.00  18143000.0           43.0        N
# 1363759             100000.0   288300.00  71221000.0           31.0        N
# 1372432             100000.0   468000.00  18143000.0           36.0        N
# 1373880             100000.0   600000.00   9134220.0            6.0        N
# 1378452              50000.0    43440.00  80530000.0           30.0        N
#
#          ... multipleCae typeOfContract topType  renewal contractDuration  \
# 814773   ...           N              W     RES        Y            32.00
# 823770   ...           N              S     COD        Y           120.00
# 840776   ...           N              S     RES        N            24.00
# 845530   ...           N              S     RES        Y            24.00
# 854379   ...           N              S     OPE        Y            48.00
# 854380   ...           N              S     OPE        Y            48.00
# 854381   ...           N              S     OPE        Y            48.00
# 854382   ...           N              S     OPE        Y            48.00
# 854383   ...           N              S     OPE        Y            48.00
# 854384   ...           N              S     OPE        Y            48.00
# 854385   ...           N              S     OPE        Y            48.00
# 854387   ...           N              S     OPE        Y            48.00
# 854388   ...           N              S     OPE        Y            48.00
# 855587   ...           N              S     OPE        Y            48.00
# 927000   ...           N              S     RES        Y            24.00
# 932637   ...           Y              U     OPE        Y            36.00
# 932638   ...           Y              U     OPE        Y            36.00
# 932639   ...           Y              U     OPE        Y            36.00
# 932641   ...           Y              U     OPE        Y            36.00
# 932648   ...           Y              U     OPE        Y            36.00
# 932649   ...           Y              U     OPE        Y            36.00
# 932650   ...           Y              U     OPE        Y            36.00
# 932651   ...           Y              U     OPE        Y            36.00
# 932652   ...           Y              U     OPE        Y            36.00
# 932654   ...           Y              U     OPE        Y            36.00
# 973708   ...           N              S     RES        Y            24.00
# 975037   ...           N              S     RES        Y            24.00
# 985069   ...           N              S     OPE        Y            18.06
# 1043734  ...           N              S     RES        Y            24.00
# 1046483  ...           N              U     OPE        N             7.00
# 1067274  ...           N              S     RES        Y            24.00
# 1071962  ...           N              S     RES        N            48.00
# 1098467  ...           N              S     OPE        Y            11.97
# 1118943  ...           Y              U     OPE        Y            24.00
# 1123051  ...           N              S     RES        Y            24.00
# 1160945  ...           N              S     NIC        Y            60.00
# 1160946  ...           N              S     NIC        Y            60.00
# 1160947  ...           N              S     NIC        Y            60.00
# 1160950  ...           N              S     NIC        Y            60.00
# 1189216  ...           N              S     NIC        N            38.00
# 1198099  ...           N              S     NIC        N            36.00
# 1229280  ...           N              S     NIC        N            41.00
# 1355969  ...           N              U     OPE        Y            48.00
# 1356689  ...           N              U     OPE        Y            11.97
# 1356690  ...           N              U     OPE        Y            11.97
# 1363759  ...           N              S     OPE        N            38.00
# 1372432  ...           N              U     OPE        N             4.00
# 1373880  ...           N              U     OPE        Y            11.97
# 1378452  ...           N              S     OPE        Y            24.00
#
#          publicityDuration  year  month cluster anomaly
# 814773                33.0  2016      4       3    True
# 823770                50.0  2016      5       3    True
# 840776                42.0  2016      8       3    True
# 845530                13.0  2016      4       3    True
# 854379                28.0  2016      6       3    True
# 854380                28.0  2016      6       3    True
# 854381                28.0  2016      6       3    True
# 854382                28.0  2016      6       3    True
# 854383                28.0  2016      6       3    True
# 854384                28.0  2016      6       3    True
# 854385                28.0  2016      6       3    True
# 854387                28.0  2016      6       3    True
# 854388                28.0  2016      6       3    True
# 855587                41.0  2016      7       3    True
# 927000                42.0  2016     12       3    True
# 932637                34.0  2017      4       3    True
# 932638                34.0  2017      4       3    True
# 932639                34.0  2017      4       3    True
# 932641                34.0  2017      4       3    True
# 932648                34.0  2017      4       3    True
# 932649                34.0  2017      4       3    True
# 932650                34.0  2017      4       3    True
# 932651                34.0  2017      4       3    True
# 932652                34.0  2017      4       3    True
# 932654                34.0  2017      4       3    True
# 973708                42.0  2017      7       3    True
# 975037                42.0  2017      5       3    True
# 985069                38.0  2017     10       3    True
# 1043734               42.0  2017     12       3    True
# 1046483               38.0  2018      3       3    True
# 1067274               42.0  2018      2       3    True
# 1071962               31.0  2018      3       3    True
# 1098467               32.0  2018      8       3    True
# 1118943               42.0  2018      9       3    True
# 1123051               42.0  2018     10       3    True
# 1160945               22.0  2019      1       3    True
# 1160946               22.0  2019      1       3    True
# 1160947               22.0  2019      1       3    True
# 1160950               22.0  2019      1       3    True
# 1189216               31.0  2019      5       3    True
# 1198099               39.0  2019      5       3    True
# 1229280               30.0  2019      7       3    True
# 1355969               33.0  2020     10       3    True
# 1356689               75.0  2020      9       3    True
# 1356690               75.0  2020      9       3    True
# 1363759               22.0  2020      9       3    True
# 1372432               32.0  2020     11       3    True
# 1373880               53.0  2020     10       3    True
# 1378452               34.0  2020     12       3    True
#
# [49 rows x 30 columns]

# %%
get_anomaly_cluster(
    data = clusters_1_anomalies, 
    clusterId = 4
)
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 159209    159209   201155574              0          0  2010-12-30
# 238774    238774  2011323434              0          0  2011-08-31
# 238775    238775  2011323434              0          0  2011-08-31
# 238776    238776  2011323434              0          0  2011-08-31
# 380438    380438  2012346937              0          0  2012-07-12
# 380439    380439  2012346937              0          0  2012-07-12
# 380440    380440  2012346937              0          0  2012-09-25
# 515461    515461  2013403085              0          0  2013-11-22
# 1289882  1289882   202070296              0          0  2020-02-03
# 1346051  1346051  2020434123              0          0  2020-07-31
# 1346052  1346052  2020434131              0          0  2020-07-31
# 1355499  1355499  2020498608              0          0  2019-11-06
#
#          awardEstimatedPrice  awardPrice         cpv  numberTenders onBehalf  \
# 159209              100000.0     69965.0  34928300.0            5.0        N
# 238774              100000.0     69965.0  45112700.0            6.0        N
# 238775              100000.0     69965.0  45112700.0            8.0        N
# 238776              100000.0     69965.0  45112700.0            3.0        N
# 380438              100000.0    299375.0  79341000.0            1.0        N
# 380439              100000.0    253774.0  79341000.0            1.0        N
# 380440              100000.0     62472.7  79341000.0            2.0        N
# 515461              100000.0    300000.0  71620000.0            8.0        N
# 1289882             100000.0    735970.0  79340000.0            5.0        N
# 1346051            2000000.0   2000000.0  30192000.0            3.0        N
# 1346052            1600000.0   1600000.0  30197630.0            2.0        N
# 1355499             100000.0    250000.0  39711362.0            5.0        Y
#
#          ... multipleCae typeOfContract topType  renewal contractDuration  \
# 159209   ...           N              U     OPE        Y             48.0
# 238774   ...           N              W     OPE        Y             24.0
# 238775   ...           N              W     OPE        Y             24.0
# 238776   ...           N              W     OPE        Y             24.0
# 380438   ...           N              S     OPE        Y             24.0
# 380439   ...           N              S     OPE        Y             24.0
# 380440   ...           N              S     OPE        Y             24.0
# 515461   ...           N              S     OPE        Y             48.0
# 1289882  ...           N              S     NIC        N             48.0
# 1346051  ...           N              U     RES        N             48.0
# 1346052  ...           N              U     RES        N             48.0
# 1355499  ...           N              U     RES        Y             24.0
#
#          publicityDuration  year  month cluster anomaly
# 159209              3694.0  2010     12       4    True
# 238774              3342.0  2011      8       4    True
# 238775              3342.0  2011      8       4    True
# 238776              3342.0  2011      8       4    True
# 380438              2964.0  2012      7       4    True
# 380439              2964.0  2012      7       4    True
# 380440              2964.0  2012      9       4    True
# 515461              2599.0  2013     11       4    True
# 1289882             1460.0  2020      2       4    True
# 1346051             1512.0  2020      7       4    True
# 1346052             1512.0  2020      7       4    True
# 1355499             1827.0  2019     11       4    True
#
# [12 rows x 30 columns]

# %% [markdown]
# # Question 5
#
# Q5: si oui, lesquelles et comment les expliquer?

# %%
cluster_1_anno_corr_cat, cluster_1_anno_corr_num = get_anomaly_corr(
    data = clusters_1_anomalies, 
    clusterId = 1, 
    num_cols = numeric_columns, 
    cat_cols = categorical_columns,
)

# %%
cluster_1_anno_corr_cat
# Out:
#                    anomaly
# cancelled         0.000000
# year              0.149068
# cpv               0.205857
# onBehalf          0.098023
# jointProcurement  0.154570
# fraAgreement      0.030373
# fraEstimated      0.023292
# accelerated       0.000000
# outOfDirectives   0.000000
# subContracted     0.003996
# gpa               0.000000
# multipleCae       0.154570
# typeOfContract    0.083759
# topType           0.006439
# renewal           0.104841

# %%
cluster_1_anno_corr_num
# Out:
#                           anomaly
# correctionsNb        0.000000e+00
# awardEstimatedPrice  8.468091e-01
# awardPrice           6.336407e-01
# numberTenders        1.215123e-06
# lotsNumber           9.168267e-01
# numberTendersSme     7.047622e-01
# contractDuration     5.220370e-01
# publicityDuration    3.505262e-14

# %%
cluster_1_data = get_cluster_data(data=clusters_1_anomalies, clusterId=1)

# %%
plot_categorial_numerical(
    data=cluster_1_data,
    title="Correlation entre anomaly et lotsNumber pour le cluster 1",
    xlabel='anomaly',
    ylabel='lotsNumber',
    saveas='../images/04_quest_lots_04.png',
    logy=True
)

# %%
plot_categorial_numerical(
    data=cluster_1_data,
    title="Correlation entre anomaly et awardEstimatedPrice pour le cluster 1",
    xlabel='anomaly',
    ylabel='awardEstimatedPrice',
    saveas='../images/04_quest_lots_05.png',
    logy=True
)

# %%
plot_categorial_numerical(
    data=cluster_1_data,
    title="Correlation entre anomaly et numberTendersSme pour le cluster 1",
    xlabel='anomaly',
    ylabel='numberTendersSme',
    saveas='../images/04_quest_lots_06.png',
    logy=True
)

# %%
cluster_3_anno_corr_cat, cluster_3_anno_corr_num = get_anomaly_corr(
    data = clusters_1_anomalies, 
    clusterId = 3, 
    num_cols = numeric_columns, 
    cat_cols = categorical_columns
)

# %%
cluster_3_anno_corr_cat
# Out:
#                    anomaly
# cancelled         0.000000
# year              0.391611
# cpv               0.844662
# onBehalf          0.281347
# jointProcurement  0.281347
# fraAgreement      0.361905
# fraEstimated      0.458453
# accelerated       0.000000
# outOfDirectives   0.000000
# subContracted     0.057569
# gpa               0.380221
# multipleCae       0.281347
# typeOfContract    0.368659
# topType           0.452253
# renewal           0.077547

# %%
cluster_3_anno_corr_num
# Out:
#                           anomaly
# correctionsNb        0.000000e+00
# awardEstimatedPrice  2.250228e-09
# awardPrice           5.063076e-18
# numberTenders        6.179505e-15
# lotsNumber           1.109299e-07
# numberTendersSme     4.758207e-05
# contractDuration     6.402138e-01
# publicityDuration    1.406268e-01

# %%
cluster_3_data = get_cluster_data(data=clusters_1_anomalies, clusterId=3)

# %%
cluster_3_data_vc = get_vc(cluster_3_data, column='cpv')

# %%
cluster_3_data_vc
# Out:
#         valeur  count  proportion
# 0   33140000.0    220   55.276382
# 1   79100000.0     48   12.060302
# 2   45215100.0     31    7.788945
# 3   15000000.0     29    7.286432
# 4   15800000.0     20    5.025126
# 5   92311000.0      9    2.261307
# 6   71250000.0      8    2.010050
# 7   71221000.0      8    2.010050
# 8   71000000.0      7    1.758794
# 9   18143000.0      5    1.256281
# 10  71200000.0      2    0.502513
# 11  71240000.0      2    0.502513
# 12  45210000.0      1    0.251256
# 13  45400000.0      1    0.251256
# 14  60130000.0      1    0.251256
# 15  18110000.0      1    0.251256
# 16  45000000.0      1    0.251256
# 17  79400000.0      1    0.251256
# 18  71420000.0      1    0.251256
# 19   9134220.0      1    0.251256
# 20  80530000.0      1    0.251256

# %%
cluster_3_cpv_cat = discretize_values(
    df=cluster_3_data_vc.copy(), 
    column='count', 
    bins=[cluster_3_data_vc['count'].min(),5, 10,cluster_3_data_vc['count'].max()],
    labels = None, 
    include_lowest=True
)

# %%
cluster_3_cpv_cat
# Out:
#         valeur  count  proportion       category
# 0   33140000.0    220   55.276382  (10.0, 220.0]
# 1   79100000.0     48   12.060302  (10.0, 220.0]
# 2   45215100.0     31    7.788945  (10.0, 220.0]
# 3   15000000.0     29    7.286432  (10.0, 220.0]
# 4   15800000.0     20    5.025126  (10.0, 220.0]
# 5   92311000.0      9    2.261307    (5.0, 10.0]
# 6   71250000.0      8    2.010050    (5.0, 10.0]
# 7   71221000.0      8    2.010050    (5.0, 10.0]
# 8   71000000.0      7    1.758794    (5.0, 10.0]
# 9   18143000.0      5    1.256281   (0.999, 5.0]
# 10  71200000.0      2    0.502513   (0.999, 5.0]
# 11  71240000.0      2    0.502513   (0.999, 5.0]
# 12  45210000.0      1    0.251256   (0.999, 5.0]
# 13  45400000.0      1    0.251256   (0.999, 5.0]
# 14  60130000.0      1    0.251256   (0.999, 5.0]
# 15  18110000.0      1    0.251256   (0.999, 5.0]
# 16  45000000.0      1    0.251256   (0.999, 5.0]
# 17  79400000.0      1    0.251256   (0.999, 5.0]
# 18  71420000.0      1    0.251256   (0.999, 5.0]
# 19   9134220.0      1    0.251256   (0.999, 5.0]
# 20  80530000.0      1    0.251256   (0.999, 5.0]

# %%
cluster_3_cpv_corr_data = get_corr_cat_2_cat_data_many_y(
    df = cluster_3_data,
    df_cat = cluster_3_cpv_cat, 
    xcol = 'anomaly', 
    ycol = 'cpv'
)

# %%
cluster_3_cpv_corr_data
# Out:
# category  (0.999, 5.0]  (5.0, 10.0]  (10.0, 220.0]
# anomaly
# False                3           14            332
# True                15           18             16

# %%
plot_categorial_categorical(
    data=cluster_3_cpv_corr_data,
    title="Correlation entre anomaly et occurences des cpv pour le cluster 3",
    xlabel="anomaly",
    ylabel="category",
    saveas='../images/04_quest_lots_07.png',
    logy=True
)

# %%
plot_categorial_numerical(
    data=cluster_3_data,
    title="Correlation entre anomaly et contractDuration pour le cluster 3",
    xlabel='anomaly',
    ylabel='contractDuration',
    saveas='../images/04_quest_lots_08.png',
    logy=True
)

# %%
cluster_4_anno_corr_cat, cluster_4_anno_corr_num = get_anomaly_corr(
    data = clusters_1_anomalies, 
    clusterId = 4, 
    num_cols = numeric_columns, 
    cat_cols = categorical_columns
)

# %%
cluster_4_anno_corr_cat
# Out:
#                    anomaly
# cancelled         0.000000
# year              0.681231
# cpv               1.000000
# onBehalf          0.458836
# jointProcurement  0.000000
# fraAgreement      0.519458
# fraEstimated      0.374665
# accelerated       0.000000
# outOfDirectives   0.000000
# subContracted     0.000000
# gpa               0.088052
# multipleCae       0.000000
# typeOfContract    0.483700
# topType           0.498286
# renewal           0.195107

# %%
cluster_4_anno_corr_num
# Out:
#                       anomaly
# correctionsNb        0.000000
# awardEstimatedPrice  0.037716
# awardPrice           0.040304
# numberTenders        0.065301
# lotsNumber           0.004105
# numberTendersSme     0.150562
# contractDuration     0.000086
# publicityDuration    0.000081

# %%
cluster_4_data = get_cluster_data(data=clusters_1_anomalies, clusterId=4)

# %%
cluster_4_data_vc = get_vc(cluster_4_data, column='cpv')

# %%
cluster_4_data_vc
# Out:
#         valeur  count  proportion
# 0   30200000.0     22   41.509434
# 1   90000000.0      9   16.981132
# 2   79400000.0      4    7.547170
# 3   32300000.0      4    7.547170
# 4   45112700.0      3    5.660377
# 5   79341000.0      3    5.660377
# 6   34928300.0      1    1.886792
# 7   71620000.0      1    1.886792
# 8   79340000.0      1    1.886792
# 9   30192000.0      1    1.886792
# 10  30197630.0      1    1.886792
# 11  38651000.0      1    1.886792
# 12  39711362.0      1    1.886792
# 13  38112100.0      1    1.886792

# %%
cluster_4_cpv_cat = discretize_values(
    df=cluster_4_data_vc.copy(), 
    column='count', 
    bins=[cluster_4_data_vc['count'].min(),5, 10,cluster_4_data_vc['count'].max()],
    labels = None, 
    include_lowest=True
)

# %%
cluster_4_cpv_cat
# Out:
#         valeur  count  proportion      category
# 0   30200000.0     22   41.509434  (10.0, 22.0]
# 1   90000000.0      9   16.981132   (5.0, 10.0]
# 2   79400000.0      4    7.547170  (0.999, 5.0]
# 3   32300000.0      4    7.547170  (0.999, 5.0]
# 4   45112700.0      3    5.660377  (0.999, 5.0]
# 5   79341000.0      3    5.660377  (0.999, 5.0]
# 6   34928300.0      1    1.886792  (0.999, 5.0]
# 7   71620000.0      1    1.886792  (0.999, 5.0]
# 8   79340000.0      1    1.886792  (0.999, 5.0]
# 9   30192000.0      1    1.886792  (0.999, 5.0]
# 10  30197630.0      1    1.886792  (0.999, 5.0]
# 11  38651000.0      1    1.886792  (0.999, 5.0]
# 12  39711362.0      1    1.886792  (0.999, 5.0]
# 13  38112100.0      1    1.886792  (0.999, 5.0]

# %%
cluster_4_cpv_corr_data = get_corr_cat_2_cat_data_many_y(
    df = cluster_4_data,
    df_cat = cluster_4_cpv_cat, 
    xcol = 'anomaly', 
    ycol = 'cpv'
)

# %%
cluster_4_cpv_corr_data
# Out:
# category  (0.999, 5.0]  (5.0, 10.0]  (10.0, 22.0]
# anomaly
# False               10            9            22
# True                12            0             0

# %%
plot_categorial_categorical(
    data=cluster_4_cpv_corr_data,
    title="Correlation entre anomaly et occurences des cpv pour le cluster 4",
    xlabel="anomaly",
    ylabel="category",
    saveas='../images/04_quest_lots_09.png',
    logy=True
)

# %%
cluster_4_year_corr_data = get_corr_cat_2_cat_data(
    df = cluster_4_data, 
    xcol = 'anomaly', 
    ycol = 'year'
)

# %%
cluster_4_year_corr_data
# Out:
# year     2010  2011  2012  2013  2015  2017  2019  2020
# anomaly
# False       0     0     6     0     9    12     7     7
# True        1     3     3     1     0     0     1     3

# %%
plot_categorial_categorical(
    data=cluster_4_year_corr_data,
    title="Correlation entre anomaly et awardDate pour le cluster 4",
    xlabel="anomaly",
    ylabel="year",
    saveas='../images/04_quest_lots_10.png',
    logy=True
)

# %% [markdown]
# # Question 6
#
# Q6: y a-t-il des différences entre agents et lots issus de secteurs d’activité différents?

# %% [markdown]
# # Question 7
#
# Q7: Si oui, lesquelles, et comment les interpréter?

# %% [markdown]
# # Question 8
#
# Q8: y a-t-il des différences entre agents et lots issus de divisions administratives différentes?

# %% [markdown]
# # Question 9
#
# Q9: Si oui, lesquelles, et comment les interpréter?

# %% [markdown]
# # Question 10
#
# Q10:Y a-t-il un lien entre l’attribution d’un contrat et la distance spatiale séparant l’acheteur et le fournisseur remportant le marché?

# %% [markdown]
# # Question 11
#
# Q11: Ou bien entre cette distance et le montant du contrat, voire une autre variable?

# %% [markdown]
# # Question 12
#
# Q12: quelle est la part des PME dans la commande publique? Par secteur? Par type d’acheteur?
