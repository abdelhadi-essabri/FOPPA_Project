# %%
from functions.utils_lots import *
import warnings

warnings.filterwarnings('ignore')

# %%
lots = load_data(path='../donnees/lots_cleaned.csv')

# %%
lots
# Out:
#            lotId    tedCanId  correctionsNb  cancelled   awardDate  \
# 0              0     2010142              0          0  2009-09-24
# 1              1     2010142              0          0  2009-09-24
# 2              2     2010142              0          0  2009-09-24
# 3              3     2010143              0          0  2009-09-28
# 4              4     2010144              0          0  2009-11-06
# ...          ...         ...            ...        ...         ...
# 1380960  1380960  2020643360              0          0  2020-12-28
# 1380961  1380961  2020643361              0          0  2020-12-10
# 1380962  1380962  2020643362              0          0  2020-12-17
# 1380963  1380963  2020643363              0          0  2020-12-11
# 1380964  1380964  2020643364              0          0  2020-12-23
#
#          awardEstimatedPrice    awardPrice         cpv  numberTenders  \
# 0                   100000.0  8.916747e+05  45233226.0            2.0
# ...

# %% [markdown]
# # Attribut lotId

# %%
lotId = lots[['lotId']]

# %%
lotId
# Out:
#            lotId
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 1380960  1380960
# 1380961  1380961
# 1380962  1380962
# 1380963  1380963
# 1380964  1380964
#
# [1380965 rows x 1 columns]

# %%
lotId_vc = get_vc(lots, column='lotId')

# %%
lotId_vc
# Out:
#           valeur  count  proportion
# 0              0      1    0.000072
# 1         920641      1    0.000072
# 2         920649      1    0.000072
# 3         920648      1    0.000072
# 4         920647      1    0.000072
# ...          ...    ...         ...
# 1380960   460320      1    0.000072
# 1380961   460319      1    0.000072
# 1380962   460318      1    0.000072
# 1380963   460317      1    0.000072
# 1380964  1380964      1    0.000072
#
# [1380965 rows x 3 columns]

# %% [markdown]
# # Attribut tedCanId

# %%
tedCanId = lots[['tedCanId']]

# %%
tedCanId
# Out:
#            tedCanId
# 0           2010142
# 1           2010142
# 2           2010142
# 3           2010143
# 4           2010144
# ...             ...
# 1380960  2020643360
# 1380961  2020643361
# 1380962  2020643362
# 1380963  2020643363
# 1380964  2020643364
#
# [1380965 rows x 1 columns]

# %%
tedCanId_vc = get_vc(lots, column='tedCanId')

# %%
tedCanId_vc
# Out:
#             valeur  count  proportion
# 0       2014304772    883    0.063941
# 1       2012153095    878    0.063579
# 2       2019505633    868    0.062855
# 3       2015214049    867    0.062782
# 4       2011362866    787    0.056989
# ...            ...    ...         ...
# 410278  2014177392      1    0.000072
# 410279  2014177391      1    0.000072
# 410280  2014177390      1    0.000072
# 410281  2014177370      1    0.000072
# 410282  2020643364      1    0.000072
#
# [410283 rows x 3 columns]

# %%
tedCanId_vc = discretize_values(
    df=tedCanId_vc, 
    column='count', 
    bins=[0, 1, 10, tedCanId_vc['count'].max()],
    labels = None, 
    include_lowest=False
)

# %%
tedCanId_vc
# Out:
#             valeur  count  proportion   category
# 0       2014304772    883    0.063941  (10, 883]
# 1       2012153095    878    0.063579  (10, 883]
# 2       2019505633    868    0.062855  (10, 883]
# 3       2015214049    867    0.062782  (10, 883]
# 4       2011362866    787    0.056989  (10, 883]
# ...            ...    ...         ...        ...
# 410278  2014177392      1    0.000072     (0, 1]
# 410279  2014177391      1    0.000072     (0, 1]
# 410280  2014177390      1    0.000072     (0, 1]
# 410281  2014177370      1    0.000072     (0, 1]
# 410282  2020643364      1    0.000072     (0, 1]
#
# [410283 rows x 4 columns]

# %%
tedCanId_vc = get_vc(tedCanId_vc, column='category')

# %%
tedCanId_vc
# Out:
#       valeur   count  proportion
# 0     (0, 1]  240176   58.539106
# 1    (1, 10]  146611   35.734115
# 2  (10, 883]   23496    5.726779

# %%
plot_proportion(
    data=tedCanId_vc,
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion des catégories des occurences de tedCanId', 
    xtitle='catégorie des occurrences', 
    ytitle='proportion',
    saveas='../images/03_desc_tedCanId_01.png',
    logy=False
)

# %% [markdown]
# # Attribut correctionsNb

# %%
correctionsNb = lots[['correctionsNb']]

# %%
correctionsNb
# Out:
#          correctionsNb
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 1380960              0
# 1380961              0
# 1380962              0
# 1380963              0
# 1380964              0
#
# [1380965 rows x 1 columns]

# %%
correctionsNb_vc = get_vc(lots, column='correctionsNb')

# %%
correctionsNb_vc
# Out:
#    valeur    count  proportion
# 0       0  1375786   99.624972
# 1       1     5089    0.368510
# 2       2       90    0.006517

# %%
plot_proportion(
    data=correctionsNb_vc,
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de correctionsNb', 
    xtitle='correctionsNb', 
    ytitle='proportion',
    saveas='../images/03_desc_correctionsNb_01.png',
    logy=True
)

# %% [markdown]
# # Attribut cancelled

# %%
cancelled = lots[['cancelled']]

# %%
cancelled
# Out:
#          cancelled
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 1380960          0
# 1380961          0
# 1380962          0
# 1380963          0
# 1380964          0
#
# [1380965 rows x 1 columns]

# %%
cancelled_vc = get_vc(lots, column='cancelled')

# %%
cancelled_vc
# Out:
#    valeur    count  proportion
# 0       0  1380685   99.979724
# 1       1      280    0.020276

# %%
plot_proportion(
    data=cancelled_vc,
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de correctionsNb', 
    xtitle='cancelled', 
    ytitle='proportion',
    saveas='../images/03_desc_cancelled_01.png',
    logy=True
)

# %% [markdown]
# # Attribut awardDate

# %%
awardDate = lots[['awardDate']]

# %%
awardDate
# Out:
#           awardDate
# 0        2009-09-24
# 1        2009-09-24
# 2        2009-09-24
# 3        2009-09-28
# 4        2009-11-06
# ...             ...
# 1380960  2020-12-28
# 1380961  2020-12-10
# 1380962  2020-12-17
# 1380963  2020-12-11
# 1380964  2020-12-23
#
# [1380965 rows x 1 columns]

# %%
awardDate_vc = get_vc(lots, column='awardDate')

# %%
awardDate_vc
# Out:
#           valeur   count  proportion
# 0     2012-01-01  188537   13.652555
# 1     2011-01-01    1675    0.121292
# 2     2010-01-01    1634    0.118323
# 3     2010-01-04    1386    0.100365
# 4     2019-12-18    1310    0.094861
# ...          ...     ...         ...
# 4367  2010-07-04       1    0.000072
# 4368  2006-12-21       1    0.000072
# 4369  2012-10-07       1    0.000072
# 4370  2001-01-04       1    0.000072
# 4371  2006-07-26       1    0.000072
#
# [4372 rows x 3 columns]

# %%
awardDate_info = get_awardDate_info(awardDate)

# %%
awardDate_info
# Out:
#          awardDate  year  month
# 0       2009-09-24  2009      9
# 1       2009-09-24  2009      9
# 2       2009-09-24  2009      9
# 3       2009-09-28  2009      9
# 4       2009-11-06  2009     11
# ...            ...   ...    ...
# 1380960 2020-12-28  2020     12
# 1380961 2020-12-10  2020     12
# 1380962 2020-12-17  2020     12
# 1380963 2020-12-11  2020     12
# 1380964 2020-12-23  2020     12
#
# [1380965 rows x 3 columns]

# %%
awardDate_year_vc = get_vc(awardDate_info, column='year')

# %%
awardDate_year_vc
# Out:
#     valeur   count  proportion
# 0     2012  300844   21.785056
# 1     2011  120070    8.694645
# 2     2010  116672    8.448585
# 3     2013  112718    8.162263
# 4     2018  109482    7.927934
# 5     2019  109373    7.920041
# 6     2017  105788    7.660440
# 7     2014  104436    7.562538
# 8     2015  103508    7.495338
# 9     2016   96433    6.983016
# 10    2020   74917    5.424975
# 11    2009   26444    1.914893
# 12    2008     219    0.015858
# 13    2007      24    0.001738
# 14    2006       9    0.000652
# 15    2001       9    0.000652
# 16    2000       7    0.000507
# 17    2005       6    0.000434
# 18    2003       1    0.000072
# 19    2004       1    0.000072
# 20    2086       1    0.000072
# 21    2068       1    0.000072
# 22    2089       1    0.000072
# 23    2002       1    0.000072

# %%
plot_proportion(
    data=awardDate_year_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par années', 
    xtitle='année', 
    ytitle='proportion',
    saveas='../images/03_desc_awardDate_01.png',
    logy=True,
    xrot=90
)

# %%
awardDate_evolution(
    df = awardDate_info, 
    start = 2010, 
    end = 2020, 
    saveas = '../images/03_desc_awardDate_02.png'
)

# %% [markdown]
# # Attribut awardEstimatedPrice

# %%
awardEstimatedPrice = lots[['awardEstimatedPrice']]

# %%
awardEstimatedPrice
# Out:
#          awardEstimatedPrice
# 0                   100000.0
# 1                   100000.0
# 2                   100000.0
# 3                   100000.0
# 4                   100000.0
# ...                      ...
# 1380960             100000.0
# 1380961             100000.0
# 1380962             100000.0
# 1380963          497000000.0
# 1380964                  1.0
#
# [1380965 rows x 1 columns]

# %%
awardEstimatedPrice_vc = get_vc(lots, column='awardEstimatedPrice')

# %%
awardEstimatedPrice_vc
# Out:
#              valeur    count  proportion
# 0      1.000000e+05  1193487   86.424131
# 1      2.000000e+05     2415    0.174878
# 2      4.000000e+05     1911    0.138381
# 3      4.000000e+04     1775    0.128533
# 4      5.000000e+04     1712    0.123971
# ...             ...      ...         ...
# 78360  4.107470e+05        1    0.000072
# 78361  2.124253e+06        1    0.000072
# 78362  8.587725e+06        1    0.000072
# 78363  4.125370e+03        1    0.000072
# 78364  4.970000e+08        1    0.000072
#
# [78365 rows x 3 columns]

# %%
awardEstimatedPrice_cat = discretize_values(
    df=awardEstimatedPrice.copy(), 
    column='awardEstimatedPrice', 
    bins=[awardEstimatedPrice['awardEstimatedPrice'].min(), 80000, 90000, 100000,awardEstimatedPrice['awardEstimatedPrice'].max()],
    labels = None, 
    include_lowest=True
)

# %%
awardEstimatedPrice_cat
# Out:
#          awardEstimatedPrice                         category
# 0                   100000.0              (90000.0, 100000.0]
# 1                   100000.0              (90000.0, 100000.0]
# 2                   100000.0              (90000.0, 100000.0]
# 3                   100000.0              (90000.0, 100000.0]
# 4                   100000.0              (90000.0, 100000.0]
# ...                      ...                              ...
# 1380960             100000.0              (90000.0, 100000.0]
# 1380961             100000.0              (90000.0, 100000.0]
# 1380962             100000.0              (90000.0, 100000.0]
# 1380963          497000000.0        (100000.0, 99999999999.0]
# 1380964                  1.0  (0.009000000000000001, 80000.0]
#
# [1380965 rows x 2 columns]

# %%
awardEstimatedPrice_cat_vc = get_vc(awardEstimatedPrice_cat, column='category')

# %%
awardEstimatedPrice_cat_vc
# Out:
#                             valeur    count  proportion
# 0              (90000.0, 100000.0]  1196145   86.616605
# 1        (100000.0, 99999999999.0]    94520    6.844489
# 2  (0.009000000000000001, 80000.0]    86561    6.268153
# 3               (80000.0, 90000.0]     3739    0.270753

# %%
plot_proportion(
    data=awardEstimatedPrice_cat_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par tranche awardEstimatedPrice', 
    xtitle='awardEstimatedPrice', 
    ytitle='proportion',
    saveas='../images/03_desc_awardEstimatedPricee_01.png',
    logy=True,
    xrot=90
)

# %%
awardEstimatedPrice.describe()
# Out:
#        awardEstimatedPrice
# count         1.380965e+06
# mean          5.041724e+05
# std           1.216732e+08
# min           1.000000e-02
# 25%           1.000000e+05
# 50%           1.000000e+05
# 75%           1.000000e+05
# max           1.000000e+11

# %% [markdown]
# # Attribut awardPrice

# %%
awardPrice = lots[['awardPrice']]

# %%
awardPrice
# Out:
#            awardPrice
# 0        8.916747e+05
# 1        1.169251e+05
# 2        7.381412e+04
# 3        3.840584e+05
# 4        7.790000e+06
# ...               ...
# 1380960  5.000000e+05
# 1380961  2.000000e+07
# 1380962  4.984029e+06
# 1380963  4.970000e+08
# 1380964  1.000000e+00
#
# [1380965 rows x 1 columns]

# %%
awardPrice_vc = get_vc(lots, column='awardPrice')

# %%
awardPrice_vc
# Out:
#               valeur   count  proportion
# 0       6.996500e+04  426326   30.871601
# 1       0.000000e+00   60518    4.382298
# 2       1.000000e+00   16662    1.206548
# 3       2.000000e+05    6156    0.445775
# 4       1.000000e+05    5652    0.409279
# ...              ...     ...         ...
# 466015  1.481150e+03       1    0.000072
# 466016  9.697200e+03       1    0.000072
# 466017  1.348770e+04       1    0.000072
# 466018  3.216600e+03       1    0.000072
# 466019  4.970000e+08       1    0.000072
#
# [466020 rows x 3 columns]

# %%
awardPrice_cat = discretize_values(
    df=awardPrice.copy(), 
    column='awardPrice', 
    bins=[awardPrice['awardPrice'].min(),9000, 100000,awardEstimatedPrice['awardEstimatedPrice'].max()],
    labels = None, 
    include_lowest=True
)

# %%
awardPrice_cat
# Out:
#            awardPrice                   category
# 0        8.916747e+05  (100000.0, 99999999999.0]
# 1        1.169251e+05  (100000.0, 99999999999.0]
# 2        7.381412e+04         (9000.0, 100000.0]
# 3        3.840584e+05  (100000.0, 99999999999.0]
# 4        7.790000e+06  (100000.0, 99999999999.0]
# ...               ...                        ...
# 1380960  5.000000e+05  (100000.0, 99999999999.0]
# 1380961  2.000000e+07  (100000.0, 99999999999.0]
# 1380962  4.984029e+06  (100000.0, 99999999999.0]
# 1380963  4.970000e+08  (100000.0, 99999999999.0]
# 1380964  1.000000e+00           (-0.001, 9000.0]
#
# [1380965 rows x 2 columns]

# %%
awardPrice_cat_vc = get_vc(awardPrice_cat, column='category')

# %%
awardPrice_cat_vc
# Out:
#                       valeur   count  proportion
# 0         (9000.0, 100000.0]  756958   54.815446
# 1  (100000.0, 99999999999.0]  411970   29.832988
# 2           (-0.001, 9000.0]  211993   15.351566

# %%
plot_proportion(
    data=awardPrice_cat_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par tranche awardPrice', 
    xtitle='awardPrice', 
    ytitle='proportion',
    saveas='../images/03_desc_awardPrice_01.png',
    logy=True,
    xrot=90
)

# %% [markdown]
# # Attribut cpv

# %%
cpv = lots[['cpv']]

# %%
cpv
# Out:
#                 cpv
# 0        45233226.0
# 1        45233226.0
# 2        45233226.0
# 3        45232150.0
# 4        45211000.0
# ...             ...
# 1380960  92200000.0
# 1380961  65111000.0
# 1380962  85312110.0
# 1380963  65300000.0
# 1380964  65310000.0
#
# [1380965 rows x 1 columns]

# %%
cpv_vc = get_vc(lots, column='cpv')

# %%
cpv_vc
# Out:
#           valeur  count  proportion
# 0     45000000.0  61435    4.448701
# 1     15800000.0  26638    1.928941
# 2     15000000.0  25823    1.869924
# 3     80530000.0  25800    1.868259
# 4     33600000.0  24926    1.804970
# ...          ...    ...         ...
# 6253  31521330.0      1    0.000072
# 6254  35341100.0      1    0.000072
# 6255  15812200.0      1    0.000072
# 6256  45213341.0      1    0.000072
# 6257  38821000.0      1    0.000072
#
# [6258 rows x 3 columns]

# %%
cpv_cat = discretize_values(
    df=cpv_vc.copy(), 
    column='count', 
    bins=[cpv_vc['count'].min(),1000, 10000,cpv_vc['count'].max()],
    labels = None, 
    include_lowest=True
)

# %%
cpv_cat
# Out:
#           valeur  count  proportion            category
# 0     45000000.0  61435    4.448701  (10000.0, 61435.0]
# 1     15800000.0  26638    1.928941  (10000.0, 61435.0]
# 2     15000000.0  25823    1.869924  (10000.0, 61435.0]
# 3     80530000.0  25800    1.868259  (10000.0, 61435.0]
# 4     33600000.0  24926    1.804970  (10000.0, 61435.0]
# ...          ...    ...         ...                 ...
# 6253  31521330.0      1    0.000072     (0.999, 1000.0]
# 6254  35341100.0      1    0.000072     (0.999, 1000.0]
# 6255  15812200.0      1    0.000072     (0.999, 1000.0]
# 6256  45213341.0      1    0.000072     (0.999, 1000.0]
# 6257  38821000.0      1    0.000072     (0.999, 1000.0]
#
# [6258 rows x 4 columns]

# %%
cpv_cat_vc = get_vc(cpv_cat, column='category')

# %%
cpv_cat_vc
# Out:
#                valeur  count  proportion
# 0     (0.999, 1000.0]   6017   96.148929
# 1   (1000.0, 10000.0]    223    3.563439
# 2  (10000.0, 61435.0]     18    0.287632

# %%
plot_proportion(
    data=cpv_cat_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title="Proportion de lots par tranche d'occurence de cpv", 
    xtitle='occurence de cpv', 
    ytitle='proportion',
    saveas='../images/03_desc_cpv_01.png',
    logy=True,
    xrot=0
)

# %% [markdown]
# # Attribut numberTenders

# %%
numberTenders = lots[['numberTenders']]

# %%
numberTenders
# Out:
#          numberTenders
# 0                  2.0
# 1                  2.0
# 2                  2.0
# 3                 11.0
# 4                  6.0
# ...                ...
# 1380960            2.0
# 1380961            2.0
# 1380962            3.0
# 1380963            1.0
# 1380964            1.0
#
# [1380965 rows x 1 columns]

# %%
numberTenders_vc = get_vc(lots, column='numberTenders')

# %%
numberTenders_vc
# Out:
#      valeur   count  proportion
# 0       2.0  598129   43.312394
# 1       3.0  167128   12.102262
# 2       1.0  151923   11.001220
# 3       4.0  129149    9.352084
# 4       5.0   89056    6.448824
# ..      ...     ...         ...
# 214   205.0       1    0.000072
# 215   170.0       1    0.000072
# 216   268.0       1    0.000072
# 217   688.0       1    0.000072
# 218   157.0       1    0.000072
#
# [219 rows x 3 columns]

# %%
numberTenders_cat = discretize_values(
    df=numberTenders.copy(), 
    column='numberTenders', 
    bins=[numberTenders['numberTenders'].min(),5, 10,numberTenders['numberTenders'].max()],
    labels = None, 
    include_lowest=True
)

# %%
numberTenders_cat
# Out:
#          numberTenders       category
# 0                  2.0  (-0.001, 5.0]
# 1                  2.0  (-0.001, 5.0]
# 2                  2.0  (-0.001, 5.0]
# 3                 11.0  (10.0, 999.0]
# 4                  6.0    (5.0, 10.0]
# ...                ...            ...
# 1380960            2.0  (-0.001, 5.0]
# 1380961            2.0  (-0.001, 5.0]
# 1380962            3.0  (-0.001, 5.0]
# 1380963            1.0  (-0.001, 5.0]
# 1380964            1.0  (-0.001, 5.0]
#
# [1380965 rows x 2 columns]

# %%
numberTenders_cat_vc = get_vc(numberTenders_cat, column='category')

# %%
numberTenders_cat_vc
# Out:
#           valeur    count  proportion
# 0  (-0.001, 5.0]  1137303   82.355672
# 1    (5.0, 10.0]   153822   11.138733
# 2  (10.0, 999.0]    89840    6.505596

# %%
plot_proportion(
    data=numberTenders_cat_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par tranche numberTenders', 
    xtitle='numberTenders', 
    ytitle='proportion',
    saveas='../images/03_desc_numberTenders_01.png',
    logy=True,
    xrot=0
)

# %% [markdown]
# # Attribut onBehalf

# %%
onBehalf = lots[['onBehalf']]

# %%
onBehalf
# Out:
#         onBehalf
# 0              N
# 1              N
# 2              N
# 3              N
# 4              N
# ...          ...
# 1380960        N
# 1380961        N
# 1380962        N
# 1380963        N
# 1380964        N
#
# [1380965 rows x 1 columns]

# %%
onBehalf_vc = get_vc(lots, column='onBehalf')

# %%
onBehalf_vc
# Out:
#   valeur    count  proportion
# 0      N  1287296   93.217134
# 1      Y    93669    6.782866

# %%
plot_proportion(
    data=onBehalf_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par onBehalf', 
    xtitle='onBehalf', 
    ytitle='proportion',
    saveas='../images/03_desc_onBehalf_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut jointProcurement

# %%
jointProcurement = lots[['jointProcurement']]

# %%
jointProcurement_vc = get_vc(lots, column='jointProcurement')

# %%
jointProcurement_vc
# Out:
#   valeur    count  proportion
# 0      N  1346323   97.491464
# 1      Y    34642    2.508536

# %%
plot_proportion(
    data=jointProcurement_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par jointProcurement', 
    xtitle='jointProcurement', 
    ytitle='proportion',
    saveas='../images/03_desc_jointProcurement_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut fraAgreement

# %%
fraAgreement = lots[['fraAgreement']]

# %%
fraAgreement_vc = get_vc(lots, column='fraAgreement')

# %%
fraAgreement_vc
# Out:
#   valeur   count  proportion
# 0      N  899503   65.135829
# 1      Y  481462   34.864171

# %%
plot_proportion(
    data=fraAgreement_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par fraAgreement', 
    xtitle='fraAgreement', 
    ytitle='proportion',
    saveas='../images/03_desc_fraAgreement_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut fraEstimated

# %%
fraEstimated = lots[['fraEstimated']]

# %%
fraEstimated
# Out:
#         fraEstimated
# 0                  K
# 1                  K
# 2                  K
# 3                  K
# 4                  K
# ...              ...
# 1380960            K
# 1380961            K
# 1380962            K
# 1380963            K
# 1380964            K
#
# [1380965 rows x 1 columns]

# %%
fraEstimated_vc = get_vc(lots, column='fraEstimated')

# %%
fraEstimated_vc
# Out:
#   valeur    count  proportion
# 0      K  1215316   88.004837
# 1      A    65544    4.746246
# 2      C    65021    4.708374
# 3     KA    20307    1.470493
# 4     AC     8893    0.643970
# 5     KC     3363    0.243525
# 6    KAC     2521    0.182554

# %%
plot_proportion(
    data=fraEstimated_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par fraEstimated', 
    xtitle='fraEstimated', 
    ytitle='proportion',
    saveas='../images/03_desc_fraEstimated_01.png',
    logy=True,
    xrot=0
)

# %% [markdown]
# # Attribut lotsNumber

# %%
lotsNumber = lots[['lotsNumber']]

# %%
lotsNumber
# Out:
#          lotsNumber
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 1380960           1
# 1380961           1
# 1380962           1
# 1380963           1
# 1380964           1
#
# [1380965 rows x 1 columns]

# %%
lotsNumber_vc = get_vc(lots, column='lotsNumber')

# %%
lotsNumber_vc
# Out:
#         valeur   count  proportion
# 0            1  523860   37.934343
# 1            2  158022   11.442868
# 2            3  107122    7.757039
# 3            4   77902    5.641128
# 4            5   58815    4.258978
# ...        ...     ...         ...
# 5345     90362       1    0.000072
# 5346    100317       1    0.000072
# 5347    100318       1    0.000072
# 5348     90361       1    0.000072
# 5349  20201102       1    0.000072
#
# [5350 rows x 3 columns]

# %%
lotsNumber_cat = discretize_values(
    df=lotsNumber.copy(), 
    column='lotsNumber', 
    bins=[lotsNumber['lotsNumber'].min(),1000, 5000,lotsNumber['lotsNumber'].max()],
    labels = None, 
    include_lowest=True
)

# %%
lotsNumber_cat
# Out:
#          lotsNumber          category
# 0                 1  (-0.001, 1000.0]
# 1                 1  (-0.001, 1000.0]
# 2                 1  (-0.001, 1000.0]
# 3                 1  (-0.001, 1000.0]
# 4                 1  (-0.001, 1000.0]
# ...             ...               ...
# 1380960           1  (-0.001, 1000.0]
# 1380961           1  (-0.001, 1000.0]
# 1380962           1  (-0.001, 1000.0]
# 1380963           1  (-0.001, 1000.0]
# 1380964           1  (-0.001, 1000.0]
#
# [1380965 rows x 2 columns]

# %%
lotsNumber_cat_vc = get_vc(lotsNumber_cat, column='category')

# %%
lotsNumber_cat_vc
# Out:
#                              valeur    count  proportion
# 0                  (-0.001, 1000.0]  1374592   99.538511
# 1  (5000.0, 2.0100243500212076e+18]     4538    0.328611
# 2                  (1000.0, 5000.0]     1835    0.132878

# %%
plot_proportion(
    data=lotsNumber_cat_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par tranche lotsNumber', 
    xtitle='lotsNumber', 
    ytitle='proportion',
    saveas='../images/03_desc_lotsNumber_01.png',
    logy=True,
    xrot=0
)

# %% [markdown]
# # Attribut accelerated

# %%
accelerated = lots[['accelerated']]

# %%
accelerated
# Out:
#         accelerated
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ...             ...
# 1380960           N
# 1380961           N
# 1380962           N
# 1380963           N
# 1380964           N
#
# [1380965 rows x 1 columns]

# %%
accelerated_vc = get_vc(lots, column='accelerated')

# %%
accelerated_vc
# Out:
#   valeur    count  proportion
# 0      N  1378410   99.814984
# 1      Y     2555    0.185016

# %%
plot_proportion(
    data=accelerated_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par accelerated', 
    xtitle='accelerated', 
    ytitle='proportion',
    saveas='../images/03_desc_accelerated_01.png',
    logy=True,
    xrot=0
)

# %% [markdown]
# # Attribut outOfDirectives

# %%
outOfDirectives = lots[['outOfDirectives']]

# %%
outOfDirectives
# Out:
#          outOfDirectives
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 1380960                0
# 1380961                0
# 1380962                0
# 1380963                0
# 1380964                0
#
# [1380965 rows x 1 columns]

# %%
outOfDirectives_vc = get_vc(lots, column='outOfDirectives')

# %%
outOfDirectives_vc
# Out:
#    valeur    count  proportion
# 0       0  1325454   95.980275
# 1       1    55511    4.019725

# %%
plot_proportion(
    data=outOfDirectives_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par outOfDirectives', 
    xtitle='outOfDirectives', 
    ytitle='proportion',
    saveas='../images/03_desc_outOfDirectives_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut contractorSme

# %%
contractorSme = lots[['contractorSme']]

# %%
contractorSme
# Out:
#         contractorSme
# 0                   N
# 1                   N
# 2                   N
# 3                   N
# 4                   N
# ...               ...
# 1380960             Y
# 1380961             N
# 1380962             N
# 1380963             N
# 1380964             N
#
# [1380965 rows x 1 columns]

# %%
contractorSme_vc = get_vc(lots, column='contractorSme')

# %%
contractorSme_vc
# Out:
#   valeur    count  proportion
# 0      N  1201668   87.016543
# 1      Y   179297   12.983457

# %%
plot_proportion(
    data=contractorSme_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par contractorSme', 
    xtitle='contractorSme', 
    ytitle='proportion',
    saveas='../images/03_desc_contractorSme_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut numberTendersSme

# %%
numberTendersSme = lots[['numberTendersSme']]

# %%
numberTendersSme
# Out:
#          numberTendersSme
# 0                     1.0
# 1                     1.0
# 2                     1.0
# 3                     1.0
# 4                     1.0
# ...                   ...
# 1380960               1.0
# 1380961               1.0
# 1380962               1.0
# 1380963               1.0
# 1380964               1.0
#
# [1380965 rows x 1 columns]

# %%
numberTendersSme_vc = get_vc(lots, column='numberTendersSme')

# %%
numberTendersSme_vc
# Out:
#     valeur    count  proportion
# 0      1.0  1348189   97.626587
# 1      0.0     8015    0.580391
# 2      2.0     7943    0.575178
# 3      3.0     5921    0.428758
# 4      4.0     3524    0.255184
# 5      5.0     2212    0.160178
# 6      6.0     1378    0.099785
# 7      7.0      825    0.059741
# 8      8.0      611    0.044244
# 9      9.0      473    0.034251
# 10    10.0      256    0.018538
# 11    11.0      212    0.015352
# 12    15.0      205    0.014845
# 13    12.0      145    0.010500
# 14    14.0      120    0.008690
# 15    13.0      115    0.008328
# 16    16.0       96    0.006952
# 17    70.0       69    0.004997
# 18    22.0       69    0.004997
# 19    68.0       61    0.004417
# 20    52.0       61    0.004417
# 21    77.0       48    0.003476
# 22    17.0       44    0.003186
# 23    21.0       39    0.002824
# 24    27.0       38    0.002752
# 25    43.0       33    0.002390
# 26    32.0       32    0.002317
# 27    19.0       28    0.002028
# ...

# %%
numberTendersSme_cat = discretize_values(
    df=numberTendersSme.copy(), 
    column='numberTendersSme', 
    bins=[numberTendersSme['numberTendersSme'].min(),1, 5,numberTendersSme['numberTendersSme'].max()],
    labels = None, 
    include_lowest=True
)

# %%
numberTendersSme_cat
# Out:
#          numberTendersSme       category
# 0                     1.0  (-0.001, 1.0]
# 1                     1.0  (-0.001, 1.0]
# 2                     1.0  (-0.001, 1.0]
# 3                     1.0  (-0.001, 1.0]
# 4                     1.0  (-0.001, 1.0]
# ...                   ...            ...
# 1380960               1.0  (-0.001, 1.0]
# 1380961               1.0  (-0.001, 1.0]
# 1380962               1.0  (-0.001, 1.0]
# 1380963               1.0  (-0.001, 1.0]
# 1380964               1.0  (-0.001, 1.0]
#
# [1380965 rows x 2 columns]

# %%
numberTendersSme_cat_vc = get_vc(numberTendersSme_cat, column='category')

# %%
numberTendersSme_cat_vc
# Out:
#           valeur    count  proportion
# 0  (-0.001, 1.0]  1356204   98.206978
# 1     (1.0, 5.0]    19600    1.419297
# 2    (5.0, 77.0]     5161    0.373724

# %%
plot_proportion(
    data=numberTendersSme_cat_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par tranche awardPrice', 
    xtitle='numberTendersSme', 
    ytitle='proportion',
    saveas='../images/03_desc_numberTendersSme_01.png',
    logy=True,
    xrot=0
)

# %% [markdown]
# # Attribut subContracted

# %%
subContracted = lots[['subContracted']]

# %%
subContracted
# Out:
#         subContracted
# 0                   N
# 1                   N
# 2                   N
# 3                   N
# 4                   N
# ...               ...
# 1380960             N
# 1380961             N
# 1380962             N
# 1380963             N
# 1380964             N
#
# [1380965 rows x 1 columns]

# %%
subContracted_vc = get_vc(lots, column='subContracted')

# %%
subContracted_vc
# Out:
#   valeur    count  proportion
# 0      N  1278937   92.611833
# 1      Y   102028    7.388167

# %%
plot_proportion(
    data=subContracted_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par subContracted', 
    xtitle='subContracted', 
    ytitle='proportion',
    saveas='../images/03_desc_subContracted_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut gpa

# %%
gpa = lots[['gpa']]

# %%
gpa
# Out:
#         gpa
# 0         Y
# 1         Y
# 2         Y
# 3         N
# 4         N
# ...      ..
# 1380960   Y
# 1380961   Y
# 1380962   Y
# 1380963   Y
# 1380964   Y
#
# [1380965 rows x 1 columns]

# %%
gpa_vc = get_vc(lots, column='gpa')

# %%
gpa_vc
# Out:
#   valeur    count  proportion
# 0      Y  1213530   87.875507
# 1      N   167435   12.124493

# %%
plot_proportion(
    data=gpa_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par gpa', 
    xtitle='gpa', 
    ytitle='proportion',
    saveas='../images/03_desc_gpa_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut multipleCae

# %%
multipleCae = lots[['multipleCae']]

# %%
multipleCae
# Out:
#         multipleCae
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ...             ...
# 1380960           N
# 1380961           N
# 1380962           N
# 1380963           N
# 1380964           N
#
# [1380965 rows x 1 columns]

# %%
multipleCae_vc = get_vc(lots, column='multipleCae')

# %%
multipleCae_vc
# Out:
#   valeur    count  proportion
# 0      N  1346708   97.519343
# 1      Y    34257    2.480657

# %%
plot_proportion(
    data=multipleCae_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par multipleCae', 
    xtitle='multipleCae', 
    ytitle='proportion',
    saveas='../images/03_desc_multipleCae_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut typeOfContract

# %%
typeOfContract = lots[['typeOfContract']]

# %%
typeOfContract
# Out:
#         typeOfContract
# 0                    W
# 1                    W
# 2                    W
# 3                    W
# 4                    W
# ...                ...
# 1380960              S
# 1380961              S
# 1380962              S
# 1380963              S
# 1380964              S
#
# [1380965 rows x 1 columns]

# %%
typeOfContract_vc = get_vc(lots, column='typeOfContract')

# %%
typeOfContract_vc
# Out:
#   valeur   count  proportion
# 0      U  554638   40.163074
# 1      S  550055   39.831205
# 2      W  276272   20.005721

# %%
plot_proportion(
    data=typeOfContract_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par typeOfContract', 
    xtitle='typeOfContract', 
    ytitle='proportion',
    saveas='../images/03_desc_typeOfContract_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut topType

# %%
topType = lots[['topType']]

# %%
topType
# Out:
#         topType
# 0           OPE
# 1           OPE
# 2           OPE
# 3           OPE
# 4           RES
# ...         ...
# 1380960     NIC
# 1380961     NIC
# 1380962     NIC
# 1380963     NOC
# 1380964     NOC
#
# [1380965 rows x 1 columns]

# %%
topType_vc = get_vc(lots, column='topType')

# %%
topType_vc
# Out:
#   valeur    count  proportion
# 0    OPE  1165587   84.403805
# 1    NIC   103848    7.519959
# 2    AWP    65077    4.712429
# 3    RES    24152    1.748922
# 4    NOC    17736    1.284319
# 5    COD     2799    0.202684
# 6    NIP     1227    0.088851
# 7    NOP      506    0.036641
# 8    INP       33    0.002390

# %%
plot_proportion(
    data=topType_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par topType', 
    xtitle='topType', 
    ytitle='proportion',
    saveas='../images/03_desc_topType_01.png',
    logy=True,
    xrot=0
)

# %% [markdown]
# # Attribut renewal

# %%
renewal = lots[['renewal']]

# %%
renewal
# Out:
#         renewal
# 0             Y
# 1             Y
# 2             Y
# 3             Y
# 4             Y
# ...         ...
# 1380960       Y
# 1380961       Y
# 1380962       Y
# 1380963       Y
# 1380964       Y
#
# [1380965 rows x 1 columns]

# %%
renewal_vc = get_vc(lots, column='renewal')

# %%
renewal_vc
# Out:
#   valeur    count  proportion
# 0      Y  1149041   83.205657
# 1      N   231924   16.794343

# %%
plot_proportion(
    data=renewal_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par renewal', 
    xtitle='renewal', 
    ytitle='proportion',
    saveas='../images/03_desc_renewal_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut contractDuration

# %%
contractDuration = lots[['contractDuration']]

# %%
contractDuration
# Out:
#          contractDuration
# 0                   24.00
# 1                   24.00
# 2                   24.00
# 3                   24.00
# 4                   24.01
# ...                   ...
# 1380960             96.00
# 1380961             24.00
# 1380962             60.00
# 1380963             24.00
# 1380964             24.00
#
# [1380965 rows x 1 columns]

# %%
contractDuration_vc = get_vc(lots, column='contractDuration')

# %%
contractDuration_vc
# Out:
#       valeur   count  proportion
# 0      24.00  586843   42.495139
# 1      12.00  215824   15.628492
# 2      48.00  145029   10.502004
# 3      36.00   57506    4.164190
# 4      11.97   54220    3.926240
# ...      ...     ...         ...
# 1981  240.30       1    0.000072
# 1982   53.42       1    0.000072
# 1983   35.39       1    0.000072
# 1984   59.47       1    0.000072
# 1985   95.63       1    0.000072
#
# [1986 rows x 3 columns]

# %%
contractDuration_cat = discretize_values(
    df=contractDuration.copy(), 
    column='contractDuration', 
    bins=[contractDuration['contractDuration'].min(),20, 30,contractDuration['contractDuration'].max()],
    labels = None, 
    include_lowest=True
)

# %%
contractDuration_cat
# Out:
#          contractDuration       category
# 0                   24.00   (20.0, 30.0]
# 1                   24.00   (20.0, 30.0]
# 2                   24.00   (20.0, 30.0]
# 3                   24.00   (20.0, 30.0]
# 4                   24.01   (20.0, 30.0]
# ...                   ...            ...
# 1380960             96.00  (30.0, 999.0]
# 1380961             24.00   (20.0, 30.0]
# 1380962             60.00  (30.0, 999.0]
# 1380963             24.00   (20.0, 30.0]
# 1380964             24.00   (20.0, 30.0]
#
# [1380965 rows x 2 columns]

# %%
contractDuration_cat_vc = get_vc(contractDuration_cat, column='category')

# %%
contractDuration_cat_vc
# Out:
#                          valeur   count  proportion
# 0                  (20.0, 30.0]  638110   46.207543
# 1  (0.028999999999999998, 20.0]  394355   28.556480
# 2                 (30.0, 999.0]  348500   25.235976

# %%
plot_proportion(
    data=contractDuration_cat_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par tranche contractDuration', 
    xtitle='contractDuration', 
    ytitle='proportion',
    saveas='../images/03_desc_contractDuration_01.png',
    logy=False,
    xrot=0
)

# %% [markdown]
# # Attribut publicityDuration

# %%
publicityDuration = lots[['publicityDuration']]

# %%
publicityDuration
# Out:
#          publicityDuration
# 0                     42.0
# 1                     42.0
# 2                     42.0
# 3                     42.0
# 4                     36.0
# ...                    ...
# 1380960               35.0
# 1380961               62.0
# 1380962               35.0
# 1380963               42.0
# 1380964               42.0
#
# [1380965 rows x 1 columns]

# %%
publicityDuration_vc = get_vc(lots, column='publicityDuration')

# %%
publicityDuration_vc
# Out:
#      valeur   count  proportion
# 0      42.0  445333   32.247957
# 1      41.0   90643    6.563743
# 2      31.0   44656    3.233681
# 3      43.0   44517    3.223615
# 4      32.0   41235    2.985955
# ..      ...     ...         ...
# 225   228.0       1    0.000072
# 226   151.0       1    0.000072
# 227   159.0       1    0.000072
# 228   197.0       1    0.000072
# 229   162.0       1    0.000072
#
# [230 rows x 3 columns]

# %%
publicityDuration_cat = discretize_values(
    df=publicityDuration.copy(), 
    column='publicityDuration', 
    bins=[publicityDuration['publicityDuration'].min(),40, 50,publicityDuration['publicityDuration'].max()],
    labels = None, 
    include_lowest=True
)

# %%
publicityDuration_cat
# Out:
#          publicityDuration         category
# 0                     42.0     (40.0, 50.0]
# 1                     42.0     (40.0, 50.0]
# 2                     42.0     (40.0, 50.0]
# 3                     42.0     (40.0, 50.0]
# 4                     36.0  (-41.001, 40.0]
# ...                    ...              ...
# 1380960               35.0  (-41.001, 40.0]
# 1380961               62.0   (50.0, 3694.0]
# 1380962               35.0  (-41.001, 40.0]
# 1380963               42.0     (40.0, 50.0]
# 1380964               42.0     (40.0, 50.0]
#
# [1380965 rows x 2 columns]

# %%
publicityDuration_cat_vc = get_vc(publicityDuration_cat, column='category')

# %%
publicityDuration_cat_vc
# Out:
#             valeur   count  proportion
# 0     (40.0, 50.0]  761587   55.148900
# 1  (-41.001, 40.0]  386652   27.998682
# 2   (50.0, 3694.0]  232726   16.852418

# %%
plot_proportion(
    data=publicityDuration_cat_vc.sort_values(by='valeur', ascending=True),
    xcol='valeur', 
    ycol='proportion', 
    title='Proportion de lots par tranche publicityDuration', 
    xtitle='publicityDuration', 
    ytitle='proportion',
    saveas='../images/03_desc_publicityDuration_01.png',
    logy=False,
    xrot=0
)
